# %% [markdown]
# # Integration of Ordinary Differential Equations Part 1
#
# This week we start discussing the integration of ordinary differential equations. Recall that ordinary differential equations (ODEs) are differential equations of a single independent variable and partial differential equations (PDEs) have multiple independent variables.  Much of the research done in astrophysics comes down to solving differential equations that are either ODEs or PDEs and there are many methods used in different contexts so we will spend several weeks on these topics.  We begin with ODEs, which are generally more straight-forward to solve. We will find that some methods for solvisng PDEs build on ODE algorithms.
#
# **Note about this notebook**
#
# This notebook might provide more frustration than previous notebooks.  Things that might be required
# * May need to install numba (`pip install numba`) -- should be easy
# * May need to install Cython (`pip install cython`) -- make take some troubleshooting to work on Mac, Windows but easy on Linux
# * You should not need to install `f2py` but you may have trouble interfacing with the Fortran compiler on Mac, Windows but easy on Linux
# * The video animations may not work without troubleshooting, but these are not essential to working through the notebook
# * Some of the output cells may be quite long if they generate lots of compiler warnings

# %% [markdown]
# ## 1 Differential Equations Review
#
# In mathematics, an ordinary differential equation (ODE) is a differential equation containing one or more functions of one independent variable and the derivatives of those functions.
#
# Given F, a function of x, y, and derivatives of y. Then an equation of the form
# $$
# F ( x , y , y' , … , y^{ (n − 1) } ) = y^{ ( n )} ,
# $$
# where
# $$
# y^{(n)} \equiv \frac{d^n y}{dx^n},
# $$
# is called an explicit ordinary differential equation of order n.
#
# More generally, an implicit ordinary differential equation of order n takes the form:
# $$
# F ( x , y , y', \dots ,   y^{( n )} ) = 0.
# $$
# In principle, it can be ${\bf F}(x,y,z,\dots,y',z',\dots,y^{(2)}...)=0$. As long as there is only one independent variable (in this case x), which means that if x is given, all other quantities are fixed.
#
# If there are more than one independent variable, it is partial differential equation:
# $$
# \frac{\partial f(x,y)}{\partial x}+\frac{\partial f(x,y)}{\partial y}=0
# $$
# We will tackle partial differential equations (PDEs) in a couple weeks.
#
# ### Equation orders
#
# First-order (the degree of the derivative on the left side, y on the right side can be any order):
# $$
# \frac{dy}{dt}=f(t,y)
# $$
# e.g.
# $$
# \frac{dy}{dt}=t^3 y^4+y^2+t
# $$
# is a first order equation.
#
# Second order: (the first derivative on the right side can be any power)
# $$
# \frac{d^2y}{dt^2}+\lambda \frac{dy}{dt}=f\left(t,\frac{dy}{dt},y\right)
# $$
# e.g.
# \begin{equation}
# \frac{d^2y}{dt^2}+\lambda \frac{dy}{dt}= 5 t^3\left(\frac{dy}{dt}\right)^5+t^7 y
# \end{equation}
# is a second order equation. In this example, t is the independent variable and y is the dependent variable.
#
# ### Linear and Nonlinear equations
#
# If only the first power of y and all $d^n y/dt^n$ appears, e.g.:
# $$
# \frac{dy}{dt}=g(t)^5 y(t)
# $$
# the equation is linear.  A nice feature of linear equations is that their solutions can be combined with any linear relations to construct new solutions. If $y_{1}(t)$ and $y_{2}(t)$ are two solutions, $\alpha y_{1}(t)+\beta y_{2}(t)$ is also the solution.
#
# The following is a non-linear equation because $y(t)$ comes in at second power on the right hand side:
# $$
# \frac{dy}{dt}=\lambda y(t)-\lambda^2 y^2(t).
# $$
#
# ### Initial and boundary conditions
#
# A solution to a first-order differential equation contains one integration constant, a solution to a second-order ODE contians two constants, etc.  These constants are set either with initial condition or boundary condition, leading to initial value and boundary value problems.
#
# ### Systems of ODEs
#
# One can express ODEs of *any order* as N first-order ODEs with dependent variables: $\mathbf{y}=\{y^0,\dots,y^{N-1}\}$. The corresponding equations can be written as
# \begin{eqnarray}
# \frac{dy_0}{dt}&=&f_0(\mathbf{y}, t)\\
# \frac{dy_1}{dt}&=&f_1(\mathbf{y}, t)\\
# ...\\
# \frac{dy_{N-1}}{dt}&=&f_{N-1}(\mathbf{y}, t)
# \end{eqnarray}
# Which can be written in a concise vector form
# $$
# \frac{d\mathbf{y}(t)}{dt}=\mathbf{f}(\mathbf{y},t)
# $$
# where $\mathbf{f}(t)=(f_0, ..., f_{N-1})$ and functions on the right hand do not contain derivatives.

# %% [markdown]
# ## 2 Solving ODEs Numerically
#
# Most methods for solving ODEs involve taking steps in the independent variable and approximating the derivative(s) numerically as finite differences.  Higher order methods generally take multiple substeps, with different algorithms differing in the number of substeps take and the finite difference expressions used.  Careful choices of these substeps can lead to higher accuracy, lower numerical cost, or preservation of some symmetry (conserved quantity).
#
# ### Euler's Method
#
# $\newcommand{\vec}[1]{{\bf #1}}$
# $\newcommand{\ee}{\end{eqnarray}}$
#
# Consider the following general expression for a first ODE.
# $$
# \frac {d\vec{y}}{dt} = \vec{f}(\vec{y}, t),
# $$
# where $\vec{y}$ is a vector of variables, $t$ is the independent variable, and $\vec{f}()$ is some arbitrary vector function of $\vec{y}$ and $t$.  We can use a forward difference expression for the derivative to write
# $$
# \frac {d\vec{y}}{dt} \approx \frac {\vec{y}_{n+1} - \vec{y}_n}{\Delta t} = \vec{f}(\vec{y}_n, t_n),\qquad (1)
# $$
# where $\Delta t = t_{n+1} - t_n$.  This is sometimes called the forward-Euler method.  This is not the only choice that could have been made, it is also possible to write it as
# $$
# \frac {\vec{y}_{n+1} - \vec{y}_n}{\Delta t} = \vec{f}(\vec{y}_{n+1}, t_{n+1}),\qquad (2)
# $$
# which is called the backward-Euler method. The derivative operator is the same in both cases, but the difference is the choice of either $t_{n}$ or $t_{n+1}$ on the right hand side.  Equation (2) gives rise to an **implicit** method. The method is called implict because $\vec{y}_{n+1}$ is not known at the start of the step, so this generally gives rise to matrix equations. Hence these can be expensive to solve (per step) and involve increase code complexity, but with the trade off that they can be more stable and allow for larger timesteps, making them ultimately faster.
#
# For now, we will focus on equation (1), which is called to **explicit** integration, since we only need $\vec{y}_{n}$, which is known at the beginning of the step. If we know the value at $\vec{y}(t_n)$, we can solve for $\vec{y}(t_{n+1})$ to be
# $$
# \vec{y}_{n+1} = \vec{y}_n + \vec{f}(\vec{y}_n, t_n)\Delta t.\qquad (3)
# $$
# This method is known as Euler's method.  If we take $\vec{f}$ to be a scalar function of just $t$, then it just becomes an ordinary integral, similar to what we have solved previously.
#
# Equation (3) gives the correct answer for $\Delta t \rightarrow 0$, but it should never be used as superior methods abound.  To see why Euler's method is not recommended, let consider the error that this algorithm introduces for finite $\Delta t$.  We do a Taylor expansion of the true solution, $\vec{y}(t)$:
# $$
# \vec{y}_{n+1} \approx \vec{y}_n + \frac{d\vec{y}}{d t}(t_n)\Delta t + \frac 1 2 \frac{d^2\vec{y}}{d t^2}(t_n)\Delta t^2 + \mathcal{O}(\Delta t^3)
# $$
# The first two terms constitute Euler's method, so for each time step, we will accumulate an error that is proportional to $\Delta t^2$.  Since the number of steps over an interval $T$ goes like $T/\Delta t$, then the total error scales like $\Delta t$.  For sufficiently small $\Delta t$, then the error is still reduced, but it comes at the cost of lots of steps.  Because of the scaling with error, Euler's method is known as a first-order method.  To get better results we want a better scaling of the error with $\Delta t$.
#
# As an example, lets consider the equation
# $$
# \frac {dy}{dt} = \cos(t).
# $$
# We can see that we can solve this analytically by noting
# $$
# y(t) = \int\cos(t) dt = \sin(t) + C,
# $$
# where $C$ is a constant.  Let see how we can do this numerically. First we define a function for the derivatives

# %%
import numpy as np

# implement the derivative above
def derivatives(t, y): 
    return np.cos(t)

# %% [markdown]
# Now you might wonder why we passed y in the derivatives function. We shall return to this shortly. Now let us define Euler method.
# $$
# y(t+\Delta t) = y(t) + \frac{dy}{dt}\Delta t
# $$
#
# ## **Student Completion**
#
# Implement the Euler's method as using $dy/dt$ using `derivatives()`.

# %%
#implement the euler's method as using dy/dt as defined by derivatives.
# derivatives has the same signature as above.

def euler(derivatives, t, delta_t, y): 
    return y + derivatives(t, y) * delta_t

# %% [markdown]
# Note that the euler function above follows the exact definition of euler's method as defined above.  Now lets drive this between $t=0$ and $t=100$

# %%
def run_euler(N=1000, t0=0, t1=100) :
    delta_t = (t1-t0)/N
    y = 0

    t_array = np.arange(t0,t1+delta_t,delta_t)
    y_array = np.zeros(t_array.size)

    y_array[0] = y
    for i in range(t_array.size-1):
        y_array[i+1] = euler(derivatives, t_array[i], delta_t, y_array[i])
    return t_array, y_array

# %% [raw]
# Great.  Now lets plot this

# %%
import matplotlib.pyplot as plt

t_array, y_array = run_euler(N=1000)
plt.plot(t_array, y_array, label='Euler')
plt.plot(t_array, np.sin(t_array), '.', label='true solution')
plt.legend()
plt.show()

print("Average Error: ",np.average(abs(y_array-np.sin(t_array))))
# Out:
# Average Error:  0.050205318634947566

# %% [markdown]
# Euler's method does ok, but we don't quite get the right values near the peaks and troughs and we needed 1000 points.  Try reducing it to $N=100$ and see how it performs.

# %% [markdown]
# ### Runge-Kutta 2 step (RK2)
#
# Euler's method is simple, but not that accurate.  There are much better methods  that are much more accurate and have other nice properties.  There is a slightly more complicated method that can give much better answers.
#
# Runge-Kutta methods are an example of predictor-corrector methods.  Such methods "predicts" the value at $\vec{y}_{n+1}$ from the current solution at $\vec{y}_n$.  Then, using this predicted value, it performs a "corrector" step to increase the accuracy of the solution.  The generic two-step Runge-Kutta method is as follows:
# $$
# \vec{k}_1 = \vec{f}(\vec{y}_n, t_n) \Delta t
# $$
# $$
# \vec{k}_2 =  \vec{f}(\vec{y}_n + \beta \vec{k}_1, t_n + \alpha \Delta t) \Delta t
# $$
# $$
# \vec{y}_{n+1} = \vec{y}_i + a \vec{k}_1 + b \vec{k}_2
# $$
# where $\vec{k}_1$ is the "predictor" subset, which is the same as an Euler step, and $\vec{k}_2$ is the "corrector" substep, and the total step ($n \rightarrow n+1$) is some linear combination of the two.  The constants, $\alpha$, $\beta$, $a$, and $b$ are chosen to make the entire algoritm accurate to $\mathcal{O}(\Delta t^3)$.  To determine these unknown constants, let perform a Taylor expansion of $\vec{y}_{n+1}$
# $$
# \vec{y}_{n+1} = \vec{y}_n + \frac{d\vec{y}}{d t}(t_n)\Delta t + \frac 1 2 \frac{d^2\vec{y}}{dt^2}(t_n)\Delta t^2
# $$
# Now
# $$
# \frac{d^2\vec{y}}{dt^2}(t_n) = \frac {d\vec{f}(\vec{y},t)}{dt} = \frac {\partial \vec{f}(\vec{y},t)}{\partial t} + \frac{d\vec{y}}{dt}\cdot\vec{\nabla}_{\vec{y}}\vec{f}
# $$
# $$
# = \frac {\partial \vec{f}(\vec{y},t)}{\partial t} + \vec{f}\cdot\vec{\nabla}_{\vec{y}}\vec{f}
# $$
# Thus we have
# $$
# \vec{y}_{n+1} = \vec{y}_n + \vec{f}(\vec{y}_n, t_n)\Delta t + \frac 1 2 \left(\frac {\partial \vec{f}(\vec{y}_n,t_n)}{\partial t} + \vec{f}(\vec{y}_n,t_n)\cdot\vec{\nabla}_{\vec{y}}\vec{f}(\vec{y}_n,t_n)\right)\Delta t^2 +\mathcal{O}(\Delta t^3)\qquad (4)
# $$
# Now we Taylor expand out $\vec{k}_2$ to find
# $$
# \vec{k}_2 = \Delta t \vec{f}(\vec{y}_n + \beta \vec{k}_1, t_n + \alpha \Delta t)
# $$
# $$
# = \Delta t\left( \vec{f}(\vec{y}_n, t_n) + \alpha\Delta t\frac {\partial \vec{f}(\vec{y}_n,t_n)}{\partial t} + \beta\Delta t \vec{f}\cdot\vec{\nabla}_{\vec{y}}\vec{f}(\vec{y}_n,t_n)\right)
# $$
# Putting this all together, we have
# $$
# \vec{y}_{n+1} = \vec{y}_n + (a+b)\Delta t \vec{f}(\vec{y}_n, t_n) + b\Delta t^2\left(\alpha\frac {\partial \vec{f}(\vec{y}_n,t_n)}{\partial t} + \beta\vec{f}\cdot\vec{\nabla}_{\vec{y}}\vec{f}(\vec{y}_n,t_n) \right)+\mathcal{O}(\Delta t^3)\qquad (5)
# $$
# Comparing Equations (4) and (5), we get the following conditions:
# $$
# a+b = 1 \qquad b\alpha = \frac 1 2 \qquad b\beta = \frac 1 2,
# $$
# which provides 3 equation for 4 unknowns.  Hence, there exist a infinite number of second order schemes that are possible, e.g., error per step that goes likes $\Delta t^3$, so the total error over a fixed interval goes like $\Delta t^2$.  So choosing $\alpha$ as a parameter, we have
# $$
# \beta = \alpha \qquad b = \frac 1 {2\alpha} \qquad a = 1 - \frac 1 {2\alpha}
# $$
# Therefore, a generic second order Runge-Kutta scheme is then
# $$
# \vec{k}_1 =  \vec{f}(\vec{y}_n, t_n)\Delta t
# $$
# $$
# \vec{k}_2 =  \vec{f}(\vec{y}_n + \alpha \vec{k}_1, t_n + \alpha \Delta t) \Delta t
# $$
# $$
# \vec{y}_{n+1} = \vec{y}_n + \left(1 - \frac 1 {2\alpha}\right) \vec{k}_1 + \frac {\vec{k}_2} {2\alpha}
# $$
#
# A few famous examples are
# 1. Midpoint method: $\alpha = 1/2$ Estimate the values of y at the midpoint and solve for the derivative at the midpoint.  Use this midpoint derivative to complete the integration.  Note that prefactor in front of $\vec{k}_1$ in this case is zero.
# 2. Heun's Method: $\alpha = 1$ Estimate the values of y at the endpoint and give equal weight to both starting and endpoints to compute the derivative.
#
# ## **Student Completion**
#
# Implement RK2 using the midpoint method, keeping it general.

# %%
#MY SOLUTION -remove
def rk2(derivatives, t, dt, y):
    k1 = derivatives(t, y)*dt
    k2 = derivatives(t+dt/2, y+k1/2)*dt
    return y + k2

# %%
# implement rk2.  derivatives have the signature derivatives(t,y) as above
def rk2(derivatives, t, dt, y):
    pass

# %%
# code for running RK2
def run_rk2(N=1000, t0=0, t1=100):
    dt = (t1-t0)/N
    y = 0
    t_array = np.arange(t0,t1+dt,dt)
    y_array = np.zeros(t_array.size)

    y_array[0] = y
    for i in range(t_array.size-1):
        y_array[i+1] = rk2(derivatives, t_array[i], dt, y_array[i])
    return t_array, y_array

# %%
import matplotlib.pyplot as plt

t_array, y_array = run_rk2(N=1000)
plt.plot(t_array, y_array, label='RK2')
plt.plot(t_array, np.sin(t_array),'.',label='true solution')
plt.legend()
plt.show()

print("Average Error: ",np.average(abs(y_array-np.sin(t_array))))
# Out:
# Average Error:  0.00026600485701528526

# %% [markdown]
# This is much more accurate that Eulers method for just a bit more computation. Try reducing it to $N=100$ and see how it performs. You should have a lower average error than Euler's method with $N=1000$ points.  This is the advantage of the higher order method!

# %% [markdown]
# ### Higher Order Methods
#
# Of course, a natural question to ask is can we got to higher than second order in $\Delta t$ and the answer is, of course, yes.  This require a large number of substeps.  For example, one can construct a fourth order Runge-Kutta (RK4) method of the form
#
# \begin{eqnarray}
#  k_1 & = & f(y_n, t_n), \\
#  k_2 & = & f\left(y_n + \Delta t \frac{k_1}{2}, t_n + \frac{\Delta t}{2}\right), \\
#  k_3 & = & f\left(y_n + \Delta t \frac{k_2}{2}, t_n + \frac{\Delta t}{2}\right), \\
#  k_4 & = & f\left(y_n + \Delta t k_3, t_n + \Delta t \right),
# \end{eqnarray}
# with
# $$
# y_{n+1} = y_n + \frac{\Delta t}{6}\left(k_1 + 2k_2 + 2k_3 + k_4 \right).
# $$
#
# We could, of course, code this up but it is useful to make use `scipy.integrate.ode()`, which provides a number of methods for higher order integration of ODEs.
#
# Let use the same example as above with a fifth order Runge-Kutta integration.

# %%
import scipy.integrate as integrate

# set up RK5
integrator = integrate.ode(derivatives).set_integrator("dopri5")
N = 1000
#set up initial conditions
y0 = np.zeros(1)
t0 = 0
t1 = 100
dt = (t1-t0)/N
integrator.set_initial_value(y0, t0)

y_array = []
t_array = []
while integrator.successful() and integrator.t < t1 : 
    integrator.integrate(integrator.t+dt)
    t_array.append(integrator.t)
    y_array.append(integrator.y[0])
     
plt.plot(t_array, y_array, label='RK5')
plt.plot(t_array, np.sin(t_array),'.',label='true solution')
plt.legend()
plt.show()

print("Average Error: ",np.average(abs(y_array-np.sin(t_array))))
# Out:
# Average Error:  1.551898994263421e-11

# %% [markdown]
# Again, we see that going to higher order results in a significant improvement in accuracy.

# %% [markdown]
# ### Adaptive Timestepping
#
# One thing that we have not discussed is the choice for $\Delta t$.  For an interval between $t_0$ and $t_1$, a larger $\Delta t$ results in fewer computational steps, which makes the calculation complete faster.  A smaller $\Delta t$, however, results in greater accuracy.
#
# In principle, one can choose the timestep to vary to compromise between accuracy and computational expense. This is particularly important for functions where the right hand side of an ODE can take on large (positive or negative) values for a limited range of the dependent variable.  In these cases, it is useful to have a variable $\Delta t$ -- small when things change quickly and large when things change slowly.
#
# Suppose you have an ODE of the form
# $$
# \frac{d y}{d t} = f(y,t)
# $$
# Then according to Euler's method we have
# $$
# y_{n+1} - y_n = f(y_n,t_n)\Delta t
# $$
# Now suppose we want the change in $\Delta y = |y_{n+1} - y_n| < \alpha |y_n|$.  This means that
# $$
# \alpha |y_n| = |f(y_n,t_n)|\Delta t_{\rm max}
# $$
# This allows us to solve for $\Delta t_{\rm max}$ to be
# $$
# \Delta t_{\rm max} = \alpha \left|\frac{y_n}{f(y_n,t_n)}\right|
# $$
# Typically, you don't want $\alpha$ to be too large nor too small, but the optimal choice will often depend on the function being integrated.  It is useful to test values on a function with similar properties whose solution is known, but values between 0.01 and 0.1 often work well.
#
# At the same time, we don't want to miss something if $\Delta t_{\rm max}$ is too large that it totally misses a change.  One can pick a $\Delta t_{\rm max,0} = (t_1 - t_0)/N_0$, where $N_0$ is a number between 10 or 100, but this may also depend on the function being integrated.
#
# So a selection for $\Delta t$ at a time $t$ would be
# $$
# \Delta t = \min( t_1 - t, \min(\Delta t_{\rm max,0}, \Delta t_{\rm max}))
# $$
#
# Now lets try an example of this. Consider the ODE
# $$
# \frac{\partial y}{\partial t} = \frac 1 {\sigma} \exp\left(-\frac{t^2}{\sigma^2}\right)
# $$
# You probably recognize the answer to this one.  Integrated from $t=-\infty$ to $\infty$, it is $\sqrt{\pi}$.
#
# ## **Student Completion**
#
# Give it a try yourself by implementing your own timestep.

# %%
# MY SOLUTION - REMOVE
def timestep(derivatives, t1, t, y, dt0, al=0.1):
    dydt = derivatives(t, y)
    if dydt == 0.:
        return min(t1-t, dt0)
    dt = al * abs(y/dydt)
    return min(t1-t, min(dt, dt0))

# %%
# write a code to compute the timestep
def timestep(derivatives, t1, t, y, dt0, al=0.1):
    pass

# %%
def gaussian(t, y, sigma=0.1):
    # prevent overflows that can happen for large exp(-t^2/sigma^2)
    if np.abs(t/sigma) > 10:
        return 0.
    return np.exp(-t**2/sigma**2)/sigma

def rk2(derivatives, t, dt, y):
    k1 = derivatives(t, y)*dt
    k2 = derivatives(t+dt/2, y+k1/2)*dt
    return y + k2

def run_gaussian(t0=-10, t1=10, N0 = 100): 
    y = 0
    t = t0
    dt0 = (t1 - t0)/N
    while t < t1 :
        dt = timestep(gaussian, t1, t, y, dt0)
        # use our RK2 implementation
        y = rk2(gaussian, t, dt, y)
        t += dt
        
    return y

print("RK2 with variable timestep: ",run_gaussian())
print("True solution: ",np.sqrt(np.pi))
# Out:
# RK2 with variable timestep:  1.7716536860195904
# True solution:  1.7724538509055159

# %% [markdown]
# ## Higher Order ODEs
#
# Thus far we have discussed the case of first order odes (ODEs with first order derivatives). As alluded to above, it is straight-fowrad to extend the methods for first order ODEs to arbitrary high order ODEs.  The trick is to simply identify higher order derivatives as variables in themselves.  Consider the ODE
# $$
# \sum_{n=1}^{N}\frac{d^n f}{dx^n} = 0
# $$
# We can write this as a sum first order ODEs by the identification of
# $$
# f_n = \frac{df_{n-1}}{dx} \qquad\textrm{and}\qquad f_0 = f
# $$
# Thus we have
# $$
# \frac{df_{N-1}}{dx} + \sum_{n=1}^{N-1} f_n = 0,
# $$
# $$
# \frac{df}{dx} = f_1
# $$
# $$
# \frac{df_1}{dx} = f_2
# $$
# $$
# \vdots
# $$
# $$
# \frac{df_{N-2}}{dx} = f_{N-1}.
# $$
# So this converts a Nth order ODE to N first order ODEs, which we can solve.
#
# As an example lets try a simple harmonic oscillator
# $$
# \frac{d^2 x}{dt^2} = -x
# $$
# We of course know that the solution is
# $$
# x(t) = A\cos(t+\phi)
# $$
#
# This is second order so we break this up into 2 first order equations
# $$
# \frac{dx}{dt} = v
# $$
# $$
# \frac{dv}{dt} = -x
# $$
# Now lets implement this numerically.

# %%
# implement the SHO derivative as 2 first order equations
def SHO_derivatives(t, y):
    x = y[0]
    v = y[1]
    return np.array([v, -x])

# %%
import numpy as np
import matplotlib.pyplot as plt

def rk2(derivatives, t, dt, y):
    k1 = derivatives(t, y)*dt
    k2 = derivatives(t+dt/2, y+k1/2)*dt
    return y + k2

# integrate from t0=0 to t
def run_SHO_rk2(t, delta_t) :
    y = np.zeros(2)
    y[0] = 1. # set initial condition
    t0 = 0.
    n = 0
    while t0 < t : 
        dt = min(t-t0 ,delta_t)
        # use our RK2 implementation
        y = rk2(SHO_derivatives, t0, dt, y)
        t0 += dt
        n += 1
        if n > 1000:
            break
    return y


y = run_SHO_rk2(2.*np.pi, 0.05)
print(y[0])
# Out:
# 1.000094410607784

# %% [markdown]
# This seems to be working.  We can make an animation using matplotlib's `animation` module. In the past I have had difficulties getting this to work in Jupyter notebooks, so **feel free to skip** if it becomes too much of a hassle.

# %%
from matplotlib.animation import FuncAnimation
from IPython import display 

fig, ax = plt.subplots()

def animate(i):
    ax.clear()
    delta_t = 0.05
    # Get the point from the points list at index i
    # Integration is done for each point -- not very efficient
    y = run_SHO_rk2(i*delta_t, delta_t)
    ax.plot(y[0], 0., color='green', marker='o')
    # Set the x and y axis to display a fixed range
    ax.set_xlim([-1.2, 1.2])
    ax.set_ylim([-1,1])


ani = FuncAnimation(fig, animate, frames=250, interval=20, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Application: N-body Dynamics
#
# The N-body problem is a classic problem in astronomy.  If two massive bodies (label i and j) interacting gravitationally, force of j on i is given by by
# $$
# \mathbf{F}_{i,j} = -\frac{G m_i m_j}{|\mathbf{r}_i - \mathbf{r}_j|^2} \hat{r},
# $$
# with
# $$
# \hat{r} = \frac{\mathbf{r}_i - \mathbf{r}_j}{|\mathbf{r}_i - \mathbf{r}_j|},
# $$
# and the force of i on j is given by $\mathbf{F}_{j,i} = - \mathbf{F}_{i,j}$.
#
# When there are more than two particles, we can find the total force on i via
# $$
# \mathbf{F}_{i} = \sum_{i \ne j} \mathbf{F}_{i,j}
# $$
#
# For N particles, this is a system of 3N second order ODEs that we transform into 6N first order ODEs, and solve simultaneously via
# $$
# \mathbf{v}_i = \frac{d\mathbf{x}_i}{dt}
# $$
# and
# $$
# \mathbf{F}_i = m_i\frac{d\mathbf{v}_i}{dt}
# $$
# ## **Student Completion**
#
# Assume you have two bodies, implement the derivatives and run it.  It should look like two bodies orbiting each other with some translational motion. Since we are doing a numerical problem, we can choose code units with $G=1$, here. Such rescalings are common in numerical simulations.

# %%
N_bodies = 2
M = np.array([1.0, 0.25])

def Nbody_derivatives(pos, vel):
# given N bodies, implement the force equations as stated above.
    dpdt = vel
    dvdt = np.zeros(vel.shape)
    for i in range(N_bodies) :
        for j in range(N_bodies) :
            if i == j : 
                continue
            ## add your code here
        
    return dpdt, dvdt

# %%
# MY SOLUTION -- Remove
N_bodies = 2
M = np.array([1.0, 0.25])

def Nbody_derivatives(pos, vel):
# given N bodies, implement the force equations as stated above.
    dpdt = vel
    dvdt = np.zeros(vel.shape)
    for i in range(N_bodies) :
        for j in range(N_bodies) :
            if i == j : 
                continue
            r = np.linalg.norm( pos[j]-pos[i])
            mass = M[j]
            rhat = (pos[i] - pos[j])/r
            dvdt[i] -= mass/(r*r)*rhat
        
    return dpdt, dvdt

# %%
# some simple initial conditions
def initial_conditions(): 
    pos_and_vel = np.zeros([N_bodies,6])

    pos_and_vel[0,0] = -1
    pos_and_vel[0,4] = -0.25
    pos_and_vel[1,0] = 1
    pos_and_vel[1,4] = 0.25
    return pos_and_vel

def run_Nbody_rk2(tend, tframe, dt):
    y = initial_conditions()
    p = y[:,0:3]
    v = y[:,3:6]
    t = 0
    tnext = tframe
    positions = []
    while t<tend :
        while t < tnext :
            # compute using rk2
            delta_t = min(tnext-t,dt)
            dpdt, dvdt = Nbody_derivatives(p, v) 
            phalf, vhalf = p+dpdt*0.5*delta_t, v+dvdt*0.5*delta_t
            dpdt, dvdt = Nbody_derivatives(phalf, vhalf)
            p, v = p + dpdt*delta_t, v + dvdt*delta_t
            t += delta_t
        positions.append(p.copy())
        tnext += tframe
    return positions

frames = 100
tframe = 0.25
dt = 0.025
positions = run_Nbody_rk2(frames*tframe, tframe, dt)

# %%
fig, ax = plt.subplots(1, 1)

def animate(i, positions):
    ax.clear()
    # Get the point from the points list at index i
    pos = positions[i]
    ax.scatter(pos[0,0], pos[0,1], color='green', marker='o')
    ax.scatter(pos[1,0], pos[1,1], color='red', marker='o')
    # Set the x and y axis to display a fixed range
    ax.set_xlim([-5, 5])
    ax.set_ylim([-5,5])
    
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=len(positions), interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# If you cannot animate, plot the trajectories
fig, ax = plt.subplots(1, 1)

for pos in positions:
    ax.scatter(pos[0,0], pos[0,1], color='green', marker='o')
    ax.scatter(pos[1,0], pos[1,1], color='red', marker='o')

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 3 Optimization and Profiling of Python Code
#
# Now that we have an introduction to ODEs, lets use this a problem to practice optimizaiton on.  As discussed in lecture, Python has a builtin profiler `cProfile` which can tell us the functions in which our program spends most of its time.
#
# Once we have identified these functions we can consider several optimatization strategies for improving code performance.

# %% [markdown]
# ### Profiling
#
# The first and most important step of optimization is to determine which functions your code spends most of its time in. It makes no sense to spend significant time optimization a function if the code spends a fraction of 1% of its time there, but functions that constitute the bulk of the time *may* be worth optimization.
#
# The Python builtin profiler is the best tool for this job.  In a Jupyter notebook, we can use the magic commands %prun or %%prun. Lets test this out using our N-body integrator, now with a larger number of masses.

# %%
import numpy as np 

N_massive = 20
N_bodies = N_massive
M = np.ones(N_bodies)

def Nbody_derivatives(pos, vel):
    dpdt = vel
    dvdt = np.zeros(vel.shape)
    for i in range(N_bodies):
        for j in range(N_bodies):
            if i == j: 
                continue
            r = np.linalg.norm(pos[j]-pos[i])
            mass = M[j]
            rhat = (pos[j] - pos[i])/r
            dvdt[i] -= mass/(r*r)*rhat
        
    return dpdt, dvdt

def initial_conditions() : 
    pos = np.random.random([N_bodies,3])
    vel = np.random.random([N_bodies,3])

    return pos, vel

def run_Nbody_rk2(tend, tframe, dt, p0, v0, derivatives):
    p, v = p0.copy(), v0.copy()
    t = 0
    tnext = tframe
    positions = [p.copy()]
    while t<tend :
        while t < tnext :
            delta_t = min(tnext-t,dt)
            dpdt, dvdt = derivatives(p,v) 
            phalf, vhalf = p+dpdt*0.5*delta_t, v+dvdt*0.5*delta_t
            dpdt, dvdt = derivatives(phalf, vhalf)
            p, v = p + dpdt*delta_t, v + dvdt*delta_t
            t += delta_t

        positions.append(p.copy())
        tnext += tframe
    return positions

# %%
tframe = 0.01
dt = 0.001
frames = 100

# use the same initial conditions for all future runs
p0, v0 = initial_conditions()

# %%
# run with profiling
# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, Nbody_derivatives)
# Out:
#          9125207 function calls (8365207 primitive calls) in 12.849 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2000    6.907    0.003   12.815    0.006 283640628.py:7(Nbody_derivatives)
#    760000    2.602    0.000    4.882    0.000 linalg.py:2349(norm)
# 1520000/760000    1.587    0.000    5.366    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    760000    0.430    0.000    5.905    0.000 <__array_function__ internals>:177(norm)
#    760000    0.386    0.000    1.583    0.000 <__array_function__ internals>:177(dot)
#    760000    0.231    0.000    0.231    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#   1520000    0.186    0.000    0.186    0.000 {built-in method builtins.issubclass}
#    760000    0.168    0.000    0.246    0.000 linalg.py:116(isComplexType)
#    760000    0.112    0.000    0.112    0.000 {built-in method numpy.asarray}
#    760000    0.109    0.000    0.109    0.000 linalg.py:2345(_norm_dispatcher)
#    760000    0.094    0.000    0.094    0.000 multiarray.py:736(dot)
#         1    0.032    0.032   12.849   12.849 283640628.py:27(run_Nbody_rk2)
#      2000    0.003    0.000    0.003    0.000 {built-in method numpy.zeros}
#      1000    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#       103    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000   12.849   12.849 {built-in method builtins.exec}
#       100    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000   12.849   12.849 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

def animate(i, positions):
    ax.clear()
    # Get the point from the points list at index i
    pos = positions[i]
    ax.scatter(pos[:,0], pos[:,1], color='green', marker='o')
    # Set the x and y axis to display a fixed range
    ax.set_xlim([-10,10])
    ax.set_ylim([-10,10])

fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=len(positions), interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# I found that the total run took 10.697 sec with cumtime of 10.669 for `Nbody_derivatives()`. (It will vary from computer to computer.) Here, cumtime is the cumulative time spend in the function and functions called from this function. Hence, almost all of the time for the N-body problem is spent evaluating the derivatives so this is the place to improve things.
#
# Now the questions is: how do we do that? Lets consider several options.

# %% [markdown]
# ### Make better use of NumPy
#
# The first thing we want to do is rewrite the code so that it is more pythonic -- mainly so that it makes better usef of Python's builtin functions.
#
# ## **Student Completion**
#
# Give it a try yourself before looking at my answer.  Maybe you can do better than me?

# %%
def Nbody_derivatives2(pos, vel):
    pass

# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, derivatives=Nbody_derivatives2)

# %% [markdown]
# My solutions is below
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %%
def Nbody_derivatives2(pos, vel):
    dpdt = vel
    dvdt = np.zeros(vel.shape)
    rvec = pos[np.newaxis,:,:] - pos[:,np.newaxis,:]
    r = np.maximum(np.linalg.norm(rvec,axis=-1),1e-30)
    dvdt = -((M[np.newaxis,:]/(r*r*r))[:,:,np.newaxis]*rvec).sum(axis=1)
    return dpdt, dvdt

# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, Nbody_derivatives2)
# Out:
#          31207 function calls in 0.164 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2000    0.066    0.000    0.143    0.000 2341833234.py:1(Nbody_derivatives2)
#      4000    0.049    0.000    0.049    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.019    0.019    0.164    0.164 283640628.py:27(run_Nbody_rk2)
#      2000    0.015    0.000    0.040    0.000 linalg.py:2349(norm)
#      2000    0.003    0.000    0.043    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      2000    0.003    0.000    0.030    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      2000    0.002    0.000    0.045    0.000 <__array_function__ internals>:177(norm)
#      2000    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#      2000    0.001    0.000    0.028    0.000 _methods.py:46(_sum)
#      1000    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      2000    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#      2000    0.001    0.000    0.001    0.000 {method 'conj' of 'numpy.ndarray' objects}
#      2000    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
#      2000    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#      2000    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#      2000    0.000    0.000    0.000    0.000 linalg.py:2345(_norm_dispatcher)
#       103    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.164    0.164 {built-in method builtins.exec}
#         1    0.000    0.000    0.164    0.164 <string>:1(<module>)
#       100    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=len(positions), interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# This was a significant speedup -- about a factor of 100!, and all we did was make better use of NumPy.  Remember that NumPy functions are mostly written in C so if we use the builtin methods and slicing effectively, we can circumvent Python's much slower performance.
#
# But this example also illustrates a pitfall of optimization.  It is less clear what the code is doing, while the for loops in the previous function are relatively clear that we are looping over every pair of particles.

# %% [markdown]
# ### Compile Python code with numba
#
# Compiling Python is becoming more popular for applications where performance matters.  A popular example is **numba**, which is a just-in-time (jit) compiler that works well with NumPy. Lets try this one, but using the original code.
#
# It is extremely easy to use.  You can just use the decorator `@jit` before the function to optimize.
#
# There are two mode of operation `nopython=True` or `False`.  When `nopython=True`, it produces much faster code, but there are limitations that can force it to fall back to `False` mode.

# %%
from numba import jit, njit

@jit(nopython=True)
def Nbody_derivatives3(pos, vel):
    dpdt = vel
    dvdt = np.zeros_like(vel)
    for i in range(N_bodies) :
        for j in range(N_bodies):
            if i == j: 
                continue
            r = np.linalg.norm(pos[j]-pos[i])
            mass = M[j]
            rhat = (pos[j] - pos[i])/r
            dvdt[i] += -mass/(r*r)*rhat
        
    return dpdt, dvdt

# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, Nbody_derivatives3)
# Note that the output %prun will likely be very long in this case
# Out:
#          598808 function calls (562762 primitive calls) in 1.127 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2000    0.380    0.000    0.382    0.000 1898012171.py:3(Nbody_derivatives3)
#      1434    0.228    0.000    0.249    0.000 ffi.py:188(__call__)
# 1245/1035    0.101    0.000    0.105    0.000 contextlib.py:117(__exit__)
#         1    0.021    0.021    1.127    1.127 283640628.py:27(run_Nbody_rk2)
# 15712/7081    0.013    0.000    0.044    0.000 {method 'format' of 'str' objects}
#     86726    0.012    0.000    0.015    0.000 {built-in method builtins.isinstance}
# 11379/2077    0.011    0.000    0.017    0.000 ir.py:317(_rec_list_vars)
# 9903/5055    0.008    0.000    0.022    0.000 pprint.py:502(_safe_repr)
#       970    0.007    0.000    0.015    0.000 {built-in method builtins.sorted}
# 9648/4013    0.007    0.000    0.042    0.000 _utils.py:44(__str__)
#      2602    0.005    0.000    0.020    0.000 instructions.py:13(__init__)
# 7061/7019    0.005    0.000    0.011    0.000 _utils.py:54(get_reference)
#      2666    0.005    0.000    0.035    0.000 values.py:544(_to_string)
#    104/26    0.004    0.000    0.719    0.028 compiler_machinery.py:268(_runPass)
# 12413/12388    0.004    0.000    0.006    0.000 {built-in method builtins.getattr}
#      3240    0.004    0.000    0.008    0.000 _utils.py:24(deduplicate)
#       108    0.003    0.000    0.019    0.000 pprint.py:345(_format_dict_items)
#      4848    0.003    0.000    0.005    0.000 pprint.py:99(_safe_tuple)
#      3190    0.003    0.000    0.016    0.000 values.py:537(__init__)
#  2595/112    0.003    0.000    0.044    0.000 pprint.py:163(_format)
#      1245    0.003    0.000    0.003    0.000 contextlib.py:82(__init__)
#      5055    0.003    0.000    0.027    0.000 pprint.py:403(_repr)
#        40    0.003    0.000    0.014    0.000 analysis.py:23(compute_use_defs)
#       107    0.003    0.000    0.005    0.000 instructions.py:68(__init__)
#      3304    0.003    0.000    0.013    0.000 values.py:557(_set_name)
#      3176    0.003    0.000    0.007    0.000 event.py:243(notify)
#      3378    0.002    0.000    0.010    0.000 event.py:209(broadcast)
#      1689    0.002    0.000    0.009    0.000 event.py:390(start_event)
# 5345/4915    0.002    0.000    0.122    0.000 {built-in method builtins.next}
#     15011    0.002    0.000    0.002    0.000 pprint.py:92(__lt__)
# 5526/5485    0.002    0.000    0.007    0.000 {method 'join' of 'str' objects}
#      1689    0.002    0.000    0.011    0.000 event.py:404(end_event)
#      3378    0.002    0.000    0.005    0.000 event.py:100(__init__)
# 10115/9907    0.002    0.000    0.006    0.000 {built-in method builtins.repr}
#      4120    0.002    0.000    0.003    0.000 targetconfig.py:111(getter)
#      3304    0.002    0.000    0.010    0.000 _utils.py:16(register)
#      6184    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
# 2980/2207    0.002    0.000    0.004    0.000 abstract.py:121(__hash__)
#      3949    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#      1252    0.002    0.000    0.006    0.000 weakref.py:382(__getitem__)
#      2140    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#      6224    0.002    0.000    0.002    0.000 _utils.py:13(is_used)
#      2602    0.002    0.000    0.002    0.000 builder.py:351(_insert)
#   557/121    0.002    0.000    0.014    0.000 context.py:343(get_meminfos)
#      1362    0.002    0.000    0.004    0.000 values.py:445(__init__)
#      4000    0.002    0.000    0.002    0.000 serialize.py:30(_numba_unpickle)
#      5055    0.002    0.000    0.024    0.000 pprint.py:412(format)
# 2328/2269    0.002    0.000    0.002    0.000 abstract.py:124(__eq__)
#     14031    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      2428    0.002    0.000    0.003    0.000 values.py:564(_get_reference)
#      2654    0.002    0.000    0.003    0.000 utils.py:497(stream_list)
# 13771/13554    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#       976    0.002    0.000    0.005    0.000 types.py:77(__call__)
#        65    0.002    0.000    0.027    0.000 functions.py:281(get_call_type)
#     10025    0.002    0.000    0.002    0.000 {method 'write' of '_io.StringIO' objects}
#       294    0.001    0.000    0.005    0.000 instructions.py:533(__init__)
#      3398    0.001    0.000    0.002    0.000 event.py:66(_guard_kind)
#      6832    0.001    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#        54    0.001    0.000    0.005    0.000 numpy_support.py:357(ufunc_find_matching_loop)
#      1588    0.001    0.000    0.002    0.000 event.py:270(on_end)
#      1434    0.001    0.000    0.010    0.000 ffi.py:70(__enter__)
#       644    0.001    0.000    0.003    0.000 instructions.py:681(descr)
#      1434    0.001    0.000    0.011    0.000 ffi.py:76(__exit__)
#        36    0.001    0.000    0.003    0.000 analysis.py:118(compute_dead_maps)
#       389    0.001    0.000    0.006    0.000 builder.py:769(store)
#       644    0.001    0.000    0.006    0.000 instructions.py:666(__init__)
#       644    0.001    0.000    0.008    0.000 builder.py:967(extract_value)
#       158    0.001    0.000    0.005    0.000 targetconfig.py:199(<dictcomp>)
#        38    0.001    0.000    0.007    0.000 cpu.py:60(load_additional_registries)
#        55    0.001    0.000    0.001    0.000 {built-in method builtins.__build_class__}
#      3176    0.001    0.000    0.001    0.000 event.py:138(is_start)
#      4752    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#   142/114    0.001    0.000    0.326    0.003 lowering.py:457(lower_inst)
#        12    0.001    0.000    0.004    0.000 postproc.py:179(_patch_var_dels)
#      3949    0.001    0.000    0.003    0.000 abc.py:96(__instancecheck__)
# 1290/1264    0.001    0.000    0.003    0.000 values.py:455(_get_reference)
#      9696    0.001    0.000    0.001    0.000 pprint.py:89(__init__)
#       182    0.001    0.000    0.003    0.000 utils.py:350(order_by_target_specificity)
#        49    0.001    0.000    0.001    0.000 {built-in method posix.stat}
# 3669/2802    0.001    0.000    0.002    0.000 {built-in method builtins.hash}
#      9233    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#   266/166    0.001    0.000    0.023    0.000 functools.py:946(__get__)
#        90    0.001    0.000    0.001    0.000 analysis.py:81(def_reach)
#      2654    0.001    0.000    0.005    0.000 templates.py:1303(new_registrations)
#      6524    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      1245    0.001    0.000    0.004    0.000 contextlib.py:238(helper)
#        96    0.001    0.000    0.003    0.000 analysis.py:235(compute_cfg_from_blocks)
#       304    0.001    0.000    0.004    0.000 base.py:352(install_registry)
#       271    0.001    0.000    0.008    0.000 cgutils.py:936(gep)
#       378    0.001    0.000    0.003    0.000 context.py:428(install_registry)
#       204    0.001    0.000    0.040    0.000 values.py:1174(<listcomp>)
#      1588    0.001    0.000    0.001    0.000 event.py:265(on_start)
#      1434    0.001    0.000    0.009    0.000 base.py:1246(exit_fn)
#       112    0.001    0.000    0.011    0.000 cgutils.py:362(alloca_once)
#      1559    0.001    0.000    0.002    0.000 types.py:30(__ne__)
#       225    0.001    0.000    0.003    0.000 context.py:542(_rate_arguments)
#        81    0.001    0.000    0.001    0.000 analysis.py:91(liveness)
#      2120    0.001    0.000    0.001    0.000 cpu_options.py:123(<genexpr>)
# 1245/1030    0.001    0.000    0.014    0.000 contextlib.py:108(__enter__)
#      2538    0.001    0.000    0.001    0.000 _utils.py:71(_stringify_metadata)
#      1434    0.001    0.000    0.008    0.000 base.py:1243(enter_fn)
#      2654    0.001    0.000    0.001    0.000 utils.py:506(sublist_iterator)
#     93/59    0.001    0.000    0.016    0.000 base.py:526(get_function)
#        36    0.001    0.000    0.029    0.001 postproc.py:71(run)
#       389    0.001    0.000    0.003    0.000 instructions.py:459(descr)
#       294    0.001    0.000    0.004    0.000 instructions.py:555(descr)
#      1669    0.001    0.000    0.015    0.000 ir.py:350(list_vars)
#      1165    0.001    0.000    0.006    0.000 manager.py:29(lookup)
#      1405    0.001    0.000    0.001    0.000 ir.py:1275(find_insts)
#       567    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        68    0.001    0.000    0.001    0.000 base.py:49(_find)
#       343    0.001    0.000    0.004    0.000 builder.py:756(load)
#      4148    0.001    0.000    0.001    0.000 abstract.py:96(key)
#       294    0.001    0.000    0.006    0.000 builder.py:922(gep)
#       121    0.001    0.000    0.016    0.000 context.py:360(_call_incref_decref)
#       998    0.001    0.000    0.001    0.000 types.py:241(format_constant)
#       636    0.001    0.000    0.004    0.000 cpu_options.py:16(__repr__)
#      5107    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#     13/10    0.001    0.000    0.328    0.033 lowering.py:275(lower_block)
#       560    0.001    0.000    0.002    0.000 numpy_support.py:339(ufunc_can_cast)
#        55    0.001    0.000    0.003    0.000 packer.py:73(__init__)
#       101    0.001    0.000    0.004    0.000 module.py:45(add_metadata)
#         8    0.001    0.000    0.012    0.001 registry.py:54(apply)
#      1110    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      3838    0.001    0.000    0.001    0.000 builder.py:195(block)
#        10    0.001    0.000    0.001    0.000 {built-in method posix.getcwd}
#        31    0.001    0.000    0.004    0.000 context.py:592(resolve_overload)
#       356    0.001    0.000    0.001    0.000 typeconv.py:40(check_compatible)
#      4253    0.001    0.000    0.001    0.000 targetconfig.py:38(default)
#      3027    0.001    0.000    0.001    0.000 values.py:554(_get_name)
#      1603    0.001    0.000    0.001    0.000 compiler.py:377(__getattr__)
#      3158    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       142    0.001    0.000    0.107    0.001 builder.py:297(if_then)
#      1123    0.001    0.000    0.008    0.000 ir.py:598(list_vars)
#       210    0.001    0.000    0.003    0.000 event.py:422(trigger_event)
#       227    0.001    0.000    0.001    0.000 values.py:1051(__init__)
#       343    0.001    0.000    0.002    0.000 instructions.py:439(descr)
#        87    0.001    0.000    0.003    0.000 typeof.py:27(typeof)
#        56    0.001    0.000    0.023    0.000 typeinfer.py:580(resolve)
#       107    0.001    0.000    0.002    0.000 instructions.py:133(_descr)
#       354    0.001    0.000    0.005    0.000 models.py:629(get)
#    142/27    0.001    0.000    0.720    0.027 compiler_lock.py:32(_acquire_compile_lock)
#       510    0.001    0.000    0.002    0.000 ffi.py:327(close)
#       358    0.001    0.000    0.005    0.000 cgutils.py:158(__setattr__)
#      2668    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#      3502    0.001    0.000    0.001    0.000 {built-in method time.perf_counter}
#        56    0.001    0.000    0.001    0.000 values.py:794(__init__)
#      2763    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#        45    0.001    0.000    0.020    0.000 cgutils.py:99(__init__)
#        53    0.001    0.000    0.008    0.000 npydecl.py:97(generic)
#       120    0.001    0.000    0.003    0.000 errors.py:517(__init__)
#       592    0.001    0.000    0.001    0.000 types.py:116(__init__)
#       172    0.001    0.000    0.001    0.000 numpy_support.py:125(as_dtype)
#        16    0.001    0.000    0.001    0.000 compiler_machinery.py:370(dependency_analysis)
#       423    0.001    0.000    0.001    0.000 controlflow.py:382(_dfs)
#      1007    0.001    0.000    0.006    0.000 manager.py:40(__getitem__)
#       299    0.001    0.000    0.005    0.000 value.py:187(name)
#       343    0.001    0.000    0.003    0.000 instructions.py:434(__init__)
#       491    0.001    0.000    0.001    0.000 values.py:860(__init__)
#      3378    0.001    0.000    0.001    0.000 event.py:108(kind)
#       164    0.001    0.000    0.002    0.000 instructions.py:349(__init__)
#      1434    0.000    0.000    0.000    0.000 ffi.py:132(__getattr__)
#       441    0.000    0.000    0.001    0.000 typeinfer.py:911(__getitem__)
#       552    0.000    0.000    0.001    0.000 errors.py:812(new_error_context)
#      3707    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       701    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10a37f960}
#        50    0.000    0.000    0.004    0.000 values.py:936(__init__)
#       389    0.000    0.000    0.004    0.000 instructions.py:455(__init__)
#      1521    0.000    0.000    0.000    0.000 controlflow.py:117(successors)
#       117    0.000    0.000    0.001    0.000 context.py:287(find_matching_getattr_template)
#       271    0.000    0.000    0.009    0.000 cgutils.py:929(gep_inbounds)
#       162    0.000    0.000    0.002    0.000 builder.py:568(_icmp)
#        42    0.000    0.000    0.003    0.000 context.py:700(load_additional_registries)
#        36    0.000    0.000    0.001    0.000 analysis.py:190(compute_live_variables)
#       176    0.000    0.000    0.002    0.000 builder.py:31(wrapped)
#       212    0.000    0.000    0.001    0.000 cpu_options.py:115(<dictcomp>)
#       205    0.000    0.000    0.001    0.000 types.py:424(wrap_constant_value)
#       204    0.000    0.000    0.002    0.000 values.py:961(append_basic_block)
#       4/1    0.000    0.000    0.720    0.720 compiler_machinery.py:342(run)
#      1588    0.000    0.000    0.000    0.000 event.py:148(is_end)
#      1588    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#    312/78    0.000    0.000    0.703    0.009 compiler_machinery.py:272(check)
#        91    0.000    0.000    0.001    0.000 ir.py:579(__repr__)
#       184    0.000    0.000    0.001    0.000 functions.py:78(add_error)
#        12    0.000    0.000    0.003    0.000 ir.py:1308(dump)
#       108    0.000    0.000    0.026    0.000 pprint.py:189(_pprint_dict)
#       294    0.000    0.000    0.002    0.000 instructions.py:556(<listcomp>)
#        29    0.000    0.000    0.001    0.000 inspect.py:2112(_signature_from_function)
#        95    0.000    0.000    0.001    0.000 interpreter.py:1797(store)
#       227    0.000    0.000    0.001    0.000 values.py:1091(_to_list)
#       407    0.000    0.000    0.007    0.000 module.py:220(__next__)
#       312    0.000    0.000    0.006    0.000 models.py:709(getter)
#      3774    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         6    0.000    0.000    0.018    0.003 codegen.py:651(_optimize_functions)
#   608/563    0.000    0.000    0.002    0.000 {built-in method builtins.any}
#       298    0.000    0.000    0.000    0.000 controlflow.py:367(_add_edge)
#       890    0.000    0.000    0.000    0.000 npytypes.py:482(key)
#       230    0.000    0.000    0.015    0.000 templates.py:349(apply)
#       110    0.000    0.000    0.002    0.000 contextlib.py:482(__exit__)
#       101    0.000    0.000    0.001    0.000 module.py:21(_fix_metadata_operands)
#       212    0.000    0.000    0.003    0.000 cpu_options.py:122(encode)
#       167    0.000    0.000    0.001    0.000 npytypes.py:523(__repr__)
#       164    0.000    0.000    0.001    0.000 instructions.py:365(descr)
#        56    0.000    0.000    0.001    0.000 typeinfer.py:508(fold_arg_vars)
#       592    0.000    0.000    0.001    0.000 values.py:575(function_type)
#       415    0.000    0.000    0.002    0.000 context.py:517(can_convert)
#         8    0.000    0.000    0.030    0.004 typeinfer.py:142(propagate)
#       489    0.000    0.000    0.002    0.000 ffi.py:370(__del__)
#     39/32    0.000    0.000    0.297    0.009 lowering.py:1185(lower_expr)
#       525    0.000    0.000    0.001    0.000 types.py:27(as_pointer)
#       224    0.000    0.000    0.002    0.000 builder.py:281(goto_entry_block)
#       348    0.000    0.000    0.001    0.000 values.py:498(__eq__)
#       243    0.000    0.000    0.001    0.000 analysis.py:66(fix_point_progress)
#        53    0.000    0.000    0.001    0.000 npydecl.py:25(_handle_inputs)
#       107    0.000    0.000    0.005    0.000 builder.py:875(call)
#       176    0.000    0.000    0.001    0.000 instructions.py:30(descr)
#        43    0.000    0.000    0.003    0.000 instructions.py:215(set_weights)
#       103    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1215    0.000    0.000    0.000    0.000 controlflow.py:125(predecessors)
#       204    0.000    0.000    0.041    0.000 values.py:1172(descr)
#       227    0.000    0.000    0.002    0.000 values.py:1104(__init__)
#       481    0.000    0.000    0.000    0.000 registry.py:96(__getitem__)
#       312    0.000    0.000    0.000    0.000 compiler_machinery.py:28(__exit__)
#        44    0.000    0.000    0.001    0.000 controlflow.py:661(_find_loops)
#        85    0.000    0.000    0.004    0.000 context.py:374(resolve_value_type)
#       127    0.000    0.000    0.002    0.000 ir.py:916(__str__)
#        15    0.000    0.000    0.001    0.000 pythonapi.py:167(__init__)
#       101    0.000    0.000    0.003    0.000 abstract.py:61(__call__)
#       204    0.000    0.000    0.001    0.000 values.py:1154(__init__)
#       112    0.000    0.000    0.044    0.000 pprint.py:151(pformat)
#       112    0.000    0.000    0.045    0.000 pprint.py:55(pformat)
#        52    0.000    0.000    0.001    0.000 controlflow.py:578(_find_back_edges)
#       105    0.000    0.000    0.000    0.000 contextlib.py:395(push)
#       100    0.000    0.000    0.001    0.000 controlflow.py:395(_eliminate_dead_blocks)
#   462/408    0.000    0.000    0.000    0.000 types.py:127(__eq__)
#       481    0.000    0.000    0.001    0.000 target_extension.py:14(__getitem__)
#       378    0.000    0.000    0.002    0.000 values.py:507(__hash__)
#        12    0.000    0.000    0.000    0.000 interpreter.py:1833(insert_block)
#       228    0.000    0.000    0.001    0.000 errors.py:470(catch_warnings)
#       527    0.000    0.000    0.000    0.000 ffi.py:337(detach)
#       847    0.000    0.000    0.001    0.000 models.py:673(get_field_position)
#        10    0.000    0.000    0.005    0.001 arrayobj.py:185(populate_array)
#       644    0.000    0.000    0.000    0.000 instructions.py:682(<listcomp>)
#        18    0.000    0.000    0.000    0.000 arraydecl.py:159(check_contiguity)
#       128    0.000    0.000    0.002    0.000 ffi.py:258(close)
#       190    0.000    0.000    0.003    0.000 value.py:250(is_declaration)
#        53    0.000    0.000    0.008    0.000 npydecl.py:201(generic)
#        23    0.000    0.000    0.011    0.000 module.py:11(parse_assembly)
#       288    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         4    0.000    0.000    0.002    0.000 interpreter.py:973(peep_hole_delete_with_exit)
#        41    0.000    0.000    0.001    0.000 common.py:49(__init__)
#       165    0.000    0.000    0.002    0.000 instructions.py:205(descr)
#       114    0.000    0.000    0.002    0.000 builder.py:738(alloca)
#       212    0.000    0.000    0.000    0.000 cpu_options.py:58(encode)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       333    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#       685    0.000    0.000    0.000    0.000 types.py:232(__eq__)
#       140    0.000    0.000    0.001    0.000 templates.py:183(signature)
#       563    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(can_cast)
#        32    0.000    0.000    0.000    0.000 values.py:47(<listcomp>)
#        19    0.000    0.000    0.047    0.002 module.py:212(<listcomp>)
#       512    0.000    0.000    0.000    0.000 ir.py:383(__getattr__)
#        77    0.000    0.000    0.000    0.000 typeof.py:66(_typeof_buffer)
#         4    0.000    0.000    0.004    0.001 byteflow.py:80(run)
#        84    0.000    0.000    0.001    0.000 ir_utils.py:2211(enforce_no_dels)
#        98    0.000    0.000    0.001    0.000 instructions.py:711(descr)
#       4/1    0.000    0.000    0.631    0.631 typed_passes.py:435(run_pass)
#         8    0.000    0.000    0.014    0.002 lowering.py:741(lower_binop)
#       111    0.000    0.000    0.000    0.000 ir.py:1264(find_exprs)
#        98    0.000    0.000    0.001    0.000 instructions.py:693(__init__)
#   869/461    0.000    0.000    0.000    0.000 packer.py:144(rec)
#       204    0.000    0.000    0.001    0.000 builder.py:357(_set_terminator)
#         8    0.000    0.000    0.001    0.000 analysis.py:291(dead_branch_prune)
#        86    0.000    0.000    0.001    0.000 builder.py:834(cbranch)
#         6    0.000    0.000    0.076    0.013 codegen.py:723(add_ir_module)
#       213    0.000    0.000    0.003    0.000 module.py:240(_next)
#        77    0.000    0.000    0.002    0.000 typeof.py:41(typeof_impl)
#       114    0.000    0.000    0.002    0.000 instructions.py:515(__init__)
#      1668    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       483    0.000    0.000    0.001    0.000 types.py:121(_to_string)
#       564    0.000    0.000    0.000    0.000 types.py:559(__eq__)
#    115/55    0.000    0.000    0.000    0.000 packer.py:175(rec)
#       582    0.000    0.000    0.001    0.000 misc.py:52(unliteral)
#       150    0.000    0.000    0.002    0.000 compiler_lock.py:15(release)
#       116    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        88    0.000    0.000    0.003    0.000 interpreter.py:1761(_dispatch)
#       112    0.000    0.000    0.000    0.000 pprint.py:104(__init__)
#        12    0.000    0.000    0.000    0.000 interpreter.py:1625(_remove_unused_temporaries)
#     63/49    0.000    0.000    0.301    0.006 lowering.py:665(lower_assign)
#         3    0.000    0.000    0.028    0.009 npyimpl.py:229(_build_array)
#       177    0.000    0.000    0.002    0.000 values.py:1123(__str__)
#       330    0.000    0.000    0.001    0.000 lowering.py:362(_disable_sroa_like_opt)
#       194    0.000    0.000    0.003    0.000 module.py:251(_next)
#       204    0.000    0.000    0.002    0.000 instructions.py:201(__init__)
#       250    0.000    0.000    0.001    0.000 builder.py:264(goto_block)
#      1328    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#       160    0.000    0.000    0.001    0.000 base.py:479(get_value_type)
#      2713    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       428    0.000    0.000    0.000    0.000 builder.py:241(position_at_end)
#      1341    0.000    0.000    0.000    0.000 analysis.py:69(<genexpr>)
#       896    0.000    0.000    0.000    0.000 ir.py:255(__hash__)
#        56    0.000    0.000    0.002    0.000 values.py:806(descr)
#       106    0.000    0.000    0.001    0.000 values.py:781(__init__)
#         4    0.000    0.000    0.001    0.000 ir_utils.py:2316(fixup_var_define_in_scope)
#       222    0.000    0.000    0.000    0.000 ir.py:1315(<genexpr>)
#     64/56    0.000    0.000    0.020    0.000 context.py:233(_resolve_user_function_type)
#        30    0.000    0.000    0.007    0.000 arrayobj.py:96(shape)
#        63    0.000    0.000    0.005    0.000 lowering.py:1465(storevar)
#         6    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#        73    0.000    0.000    0.008    0.000 lowering.py:1567(decref)
#       160    0.000    0.000    0.000    0.000 __init__.py:502(cast)
#        89    0.000    0.000    0.002    0.000 byteflow.py:319(dispatch)
#        41    0.000    0.000    0.001    0.000 npytypes.py:444(__init__)
#      1588    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       386    0.000    0.000    0.000    0.000 value.py:117(__init__)
#        15    0.000    0.000    0.008    0.001 callconv.py:868(call_function)
#        50    0.000    0.000    0.003    0.000 values.py:973(descr_prototype)
#        29    0.000    0.000    0.002    0.000 inspect.py:2206(_signature_from_callable)
#        63    0.000    0.000    0.000    0.000 api.py:952(_builtin_function_type)
#       108    0.000    0.000    0.001    0.000 numpy_support.py:387(choose_types)
#       334    0.000    0.000    0.000    0.000 types.py:445(elements)
#        21    0.000    0.000    0.001    0.000 arraydecl.py:21(get_array_index_type)
#      1215    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       182    0.000    0.000    0.001    0.000 target_extension.py:52(get_local_target)
#        48    0.000    0.000    0.002    0.000 cgutils.py:656(pack_array)
#       100    0.000    0.000    0.000    0.000 controlflow.py:88(__init__)
#        90    0.000    0.000    0.001    0.000 typeinfer.py:1092(add_type)
#        77    0.000    0.000    0.001    0.000 api.py:194(typeof)
#       165    0.000    0.000    0.001    0.000 instructions.py:207(<listcomp>)
#       109    0.000    0.000    0.000    0.000 inspect.py:2477(__init__)
#         4    0.000    0.000    0.014    0.004 interpreter.py:1352(interpret)
#       150    0.000    0.000    0.002    0.000 compiler_lock.py:11(acquire)
#       500    0.000    0.000    0.000    0.000 ffi.py:320(__init__)
#         4    0.000    0.000    0.002    0.001 lowering.py:373(_find_singly_assigned_variable)
#       317    0.000    0.000    0.000    0.000 models.py:684(get_type)
#       212    0.000    0.000    0.001    0.000 cpu_options.py:112(_get_values)
#        50    0.000    0.000    0.000    0.000 values.py:890(__init__)
#        98    0.000    0.000    0.002    0.000 builder.py:977(insert_value)
#       281    0.000    0.000    0.000    0.000 lowering.py:322(typeof)
#         4    0.000    0.000    0.144    0.036 npyimpl.py:335(numpy_ufunc_kernel)
#       204    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        13    0.000    0.000    0.002    0.000 inline_closurecall.py:1414(_inline_const_arraycall)
#       359    0.000    0.000    0.000    0.000 enum.py:343(__getitem__)
#     91/49    0.000    0.000    0.001    0.000 packer.py:123(_assign_names)
#       921    0.000    0.000    0.000    0.000 templates.py:50(args)
#         3    0.000    0.000    0.014    0.005 arrayobj.py:4156(_empty_nd_impl)
#       356    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#        62    0.000    0.000    0.000    0.000 models.py:103(traverse_types)
#        65    0.000    0.000    0.008    0.000 lowering.py:1511(delvar)
#       305    0.000    0.000    0.001    0.000 functions.py:230(_unlit_non_poison)
#       304    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       481    0.000    0.000    0.000    0.000 utils.py:376(key)
#       114    0.000    0.000    0.000    0.000 warnings.py:462(__enter__)
#       126    0.000    0.000    0.000    0.000 builder.py:211(module)
#        88    0.000    0.000    0.000    0.000 byteflow.py:1595(append)
#        92    0.000    0.000    0.002    0.000 interpreter.py:1492(_iter_inst)
#        17    0.000    0.000    0.007    0.000 base.py:412(declare_function)
#       312    0.000    0.000    0.000    0.000 compiler_machinery.py:24(__enter__)
#       416    0.000    0.000    0.000    0.000 compiler_machinery.py:429(is_registered)
#        52    0.000    0.000    0.001    0.000 models.py:715(<listcomp>)
#       100    0.000    0.000    0.005    0.000 cgutils.py:166(__getitem__)
#       657    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        77    0.000    0.000    0.001    0.000 cffi_utils.py:39(is_cffi_func)
#        31    0.000    0.000    0.017    0.001 arrayobj.py:76(_make_refs)
#       445    0.000    0.000    0.000    0.000 types.py:206(__new__)
#       114    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        36    0.000    0.000    0.004    0.000 analysis.py:60(compute_live_map)
#       603    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.006    0.002 inline_closurecall.py:80(run)
#        17    0.000    0.000    0.003    0.000 callconv.py:813(decorate_function)
#        88    0.000    0.000    0.004    0.000 cgutils.py:173(__setitem__)
#       184    0.000    0.000    0.002    0.000 base.py:42(find)
#       256    0.000    0.000    0.001    0.000 instructions.py:134(descr_arg)
#        26    0.000    0.000    0.002    0.000 callconv.py:736(check_try_status)
#        53    0.000    0.000    0.000    0.000 numpy_support.py:276(supported_ufunc_loop)
#       189    0.000    0.000    0.001    0.000 values.py:452(_to_string)
#       222    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       376    0.000    0.000    0.000    0.000 builder.py:204(function)
#        81    0.000    0.000    0.001    0.000 numbers.py:1363(constant_integer)
#       284    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       158    0.000    0.000    0.005    0.000 targetconfig.py:196(values)
#       218    0.000    0.000    0.007    0.000 cgutils.py:142(_get_ptr_by_index)
#        46    0.000    0.000    0.021    0.000 typeinfer.py:699(__call__)
#        68    0.000    0.000    0.002    0.000 cgutils.py:682(unpack_tuple)
#        80    0.000    0.000    0.000    0.000 ir.py:1535(get_definition)
#        23    0.000    0.000    0.001    0.000 cgutils.py:736(get_item_pointer2)
#     89/85    0.000    0.000    0.004    0.000 base.py:500(get_constant_generic)
#       144    0.000    0.000    0.000    0.000 context.py:455(_lookup_global)
#         3    0.000    0.000    0.252    0.084 array_exprs.py:354(_lower_array_expr)
#         8    0.000    0.000    0.000    0.000 ir_utils.py:1563(build_definitions)
#       117    0.000    0.000    0.000    0.000 context.py:250(_get_attribute_templates)
#      1030    0.000    0.000    0.000    0.000 types.py:247(wrap_constant_value)
#         8    0.000    0.000    0.002    0.000 pythonapi.py:1373(serialize_uncached)
#        72    0.000    0.000    0.003    0.000 analysis.py:71(fix_point)
#       167    0.000    0.000    0.000    0.000 controlflow.py:601(push_state)
#      1178    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        45    0.000    0.000    0.002    0.000 arrayobj.py:43(set_range_metadata)
#       144    0.000    0.000    0.000    0.000 templates.py:38(__init__)
#        42    0.000    0.000    0.001    0.000 context.py:415(_load_builtins)
#       101    0.000    0.000    0.001    0.000 abstract.py:49(_intern)
#       406    0.000    0.000    0.000    0.000 debuginfo.py:16(suspend_emission)
#         4    0.000    0.000    0.000    0.000 untyped_passes.py:304(run_pass)
#      1034    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#       151    0.000    0.000    0.000    0.000 values.py:1114(add_attribute)
#       100    0.000    0.000    0.005    0.000 cgutils.py:149(__getattr__)
#       576    0.000    0.000    0.000    0.000 ir.py:1318(terminator)
#       106    0.000    0.000    0.000    0.000 module.py:138(add_global)
#        15    0.000    0.000    0.002    0.000 callconv.py:777(_get_return_status)
#        13    0.000    0.000    0.004    0.000 callconv.py:397(set_static_user_exc)
#       157    0.000    0.000    0.001    0.000 functions.py:305(<listcomp>)
#        69    0.000    0.000    0.000    0.000 _utils.py:9(__init__)
#       204    0.000    0.000    0.000    0.000 values.py:1188(_format_name)
#       229    0.000    0.000    0.000    0.000 values.py:875(_to_list)
#       552    0.000    0.000    0.000    0.000 templates.py:361(<genexpr>)
#       181    0.000    0.000    0.001    0.000 _collections_abc.py:742(__iter__)
#       128    0.000    0.000    0.003    0.000 lowering.py:1422(_alloca_var)
#       160    0.000    0.000    0.000    0.000 os.py:668(__getitem__)
#       298    0.000    0.000    0.001    0.000 controlflow.py:102(add_edge)
#         8    0.000    0.000    0.000    0.000 {function CloudPickler.dump at 0x127799d30}
#        37    0.000    0.000    0.000    0.000 instructions.py:334(descr)
#        31    0.000    0.000    0.004    0.000 templates.py:272(_select)
#       153    0.000    0.000    0.000    0.000 values.py:870(add)
#        95    0.000    0.000    0.000    0.000 cpu.py:116(call_conv)
#       114    0.000    0.000    0.000    0.000 instructions.py:521(descr)
#        64    0.000    0.000    0.000    0.000 ffi.py:253(__init__)
#        29    0.000    0.000    0.000    0.000 inspect.py:2760(__init__)
#        80    0.000    0.000    0.000    0.000 traceback.py:216(clear_frames)
#       312    0.000    0.000    0.000    0.000 compiler_machinery.py:432(get)
#       176    0.000    0.000    0.001    0.000 instructions.py:34(<listcomp>)
#         7    0.000    0.000    0.007    0.001 arrayobj.py:374(basic_indexing)
#        19    0.000    0.000    0.000    0.000 packer.py:132(argument_types)
#       603    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#       106    0.000    0.000    0.000    0.000 ir.py:1156(define)
#       183    0.000    0.000    0.002    0.000 builder.py:248(append_basic_block)
#        83    0.000    0.000    0.001    0.000 lowering.py:1447(loadvar)
#       114    0.000    0.000    0.000    0.000 warnings.py:481(__exit__)
#        60    0.000    0.000    0.000    0.000 posixpath.py:71(join)
#         8    0.000    0.000    0.005    0.001 codegen.py:1091(<setcomp>)
#       395    0.000    0.000    0.000    0.000 __init__.py:1412(debug)
#         8    0.000    0.000    0.001    0.000 untyped_passes.py:182(run_pass)
#        80    0.000    0.000    0.000    0.000 utils.py:37(erase_traceback)
#        39    0.000    0.000    0.000    0.000 templates.py:98(__repr__)
#       101    0.000    0.000    0.003    0.000 cgutils.py:417(get_or_insert_function)
#         9    0.000    0.000    0.003    0.000 types.py:33(_get_ll_pointer_type)
#         8    0.000    0.000    0.000    0.000 executionengine.py:138(_find_module_ptr)
#         4    0.000    0.000    0.002    0.000 typed_passes.py:614(run_pass)
#        19    0.000    0.000    0.002    0.000 callconv.py:801(get_function_type)
#        38    0.000    0.000    0.011    0.000 base.py:261(refresh)
#      82/6    0.000    0.000    0.000    0.000 ast.py:158(_fix)
#        10    0.000    0.000    0.009    0.001 npyimpl.py:160(_prepare_argument)
#       108    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#       334    0.000    0.000    0.000    0.000 types.py:353(__init__)
#       200    0.000    0.000    0.000    0.000 compiler_machinery.py:385(resolve_requires)
#        36    0.000    0.000    0.004    0.000 postproc.py:46(livemap)
#         4    0.000    0.000    0.002    0.001 lowering.py:310(setup_function)
#        50    0.000    0.000    0.002    0.000 values.py:943(<listcomp>)
#         4    0.000    0.000    0.000    0.000 ir_utils.py:2031(raise_on_unsupported_feature)
#       164    0.000    0.000    0.000    0.000 ir.py:595(<genexpr>)
#        64    0.000    0.000    0.002    0.000 typeinfer.py:1453(typeof_assign)
#        87    0.000    0.000    0.003    0.000 functools.py:869(wrapper)
#        23    0.000    0.000    0.001    0.000 context.py:8(get_global_context)
#        36    0.000    0.000    0.003    0.000 transforms.py:283(canonicalize_cfg_single_backedge)
#        55    0.000    0.000    0.003    0.000 base.py:319(get_arg_packer)
#        19    0.000    0.000    0.047    0.002 module.py:207(_get_body_lines)
#        65    0.000    0.000    0.000    0.000 functions.py:65(__init__)
#       104    0.000    0.000    0.000    0.000 compiler_machinery.py:188(_validate_pass)
#        31    0.000    0.000    0.001    0.000 arrayobj.py:62(make_array)
#         4    0.000    0.000    0.004    0.001 lowering.py:29(__init__)
#       144    0.000    0.000    0.000    0.000 utils.py:467(__setitem__)
#        79    0.000    0.000    0.001    0.000 builder.py:826(branch)
#       227    0.000    0.000    0.002    0.000 values.py:979(<genexpr>)
#       115    0.000    0.000    0.000    0.000 interpreter.py:1815(get)
#       114    0.000    0.000    0.001    0.000 warnings.py:165(simplefilter)
#         1    0.000    0.000    0.013    0.013 callwrapper.py:126(build_wrapper)
#       220    0.000    0.000    0.000    0.000 types.py:519(gep)
#       165    0.000    0.000    0.000    0.000 numpy_support.py:86(from_dtype)
#       288    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       142    0.000    0.000    0.001    0.000 inline_closurecall.py:1553(list_var_used)
#        95    0.000    0.000    0.000    0.000 byteflow.py:1577(make_temp)
#       481    0.000    0.000    0.001    0.000 target_extension.py:120(inherits_from)
#         6    0.000    0.000    0.022    0.004 lowering.py:811(lower_getitem)
#       112    0.000    0.000    0.000    0.000 typeinfer.py:54(add_type)
#        79    0.000    0.000    0.000    0.000 models.py:496(traverse)
#        36    0.000    0.000    0.007    0.000 postproc.py:52(deadmaps)
#        13    0.000    0.000    0.000    0.000 lowering.py:412(pre_block)
#       285    0.000    0.000    0.000    0.000 models.py:48(get_argument_type)
#        40    0.000    0.000    0.000    0.000 typeinfer.py:1649(typeof_expr)
#       606    0.000    0.000    0.000    0.000 postproc.py:191(<genexpr>)
#       294    0.000    0.000    0.000    0.000 types.py:137(gep)
#       330    0.000    0.000    0.000    0.000 types.py:360(__getitem__)
#       197    0.000    0.000    0.000    0.000 ir.py:706(__init__)
#       150    0.000    0.000    0.002    0.000 compiler_lock.py:22(__exit__)
#        57    0.000    0.000    0.002    0.000 context.py:263(resolve_getattr)
#        49    0.000    0.000    0.001    0.000 callconv.py:838(type_may_always_need_nrt)
#        73    0.000    0.000    0.000    0.000 typeinfer.py:1180(check_var)
#        36    0.000    0.000    0.003    0.000 transforms.py:353(canonicalize_cfg)
#       271    0.000    0.000    0.001    0.000 ir_utils.py:2216(<listcomp>)
#         4    0.000    0.000    0.010    0.002 untyped_passes.py:212(run_pass)
#       304    0.000    0.000    0.001    0.000 base.py:368(insert_func_defn)
#        11    0.000    0.000    0.110    0.010 base.py:844(compile_subroutine)
#        87    0.000    0.000    0.000    0.000 functools.py:813(dispatch)
#        54    0.000    0.000    0.000    0.000 lowering.py:404(<listcomp>)
#       208    0.000    0.000    0.000    0.000 compiler_machinery.py:139(__init__)
#       553    0.000    0.000    0.000    0.000 common.py:27(_is_shutting_down)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:934(fillFormat)
#        21    0.000    0.000    0.000    0.000 packer.py:190(unflatten)
#         4    0.000    0.000    0.033    0.008 typed_passes.py:66(type_inference_stage)
#        36    0.000    0.000    0.000    0.000 misc.py:90(__init__)
#       4/1    0.000    0.000    0.328    0.328 lowering.py:250(lower_function_body)
#       323    0.000    0.000    0.000    0.000 controlflow.py:95(add_node)
#       358    0.000    0.000    0.000    0.000 abstract.py:118(__str__)
#        93    0.000    0.000    0.000    0.000 bytecode.py:281(<genexpr>)
#       327    0.000    0.000    0.000    0.000 templates.py:46(return_type)
#         4    0.000    0.000    0.034    0.008 typed_passes.py:103(run_pass)
#        11    0.000    0.000    0.010    0.001 base.py:893(call_internal_no_propagate)
#       922    0.000    0.000    0.000    0.000 {function TypeVarMap.__getitem__ at 0x128dca0d0}
#        14    0.000    0.000    0.000    0.000 array_exprs.py:33(match)
#        52    0.000    0.000    0.001    0.000 controlflow.py:206(_back_edges)
#       107    0.000    0.000    0.001    0.000 instructions.py:140(<listcomp>)
#        39    0.000    0.000    0.000    0.000 instructions.py:237(descr)
#       130    0.000    0.000    0.000    0.000 enum.py:278(__call__)
#         4    0.000    0.000    0.225    0.056 codegen.py:739(finalize)
#       170    0.000    0.000    0.001    0.000 builder.py:290(_branch_helper)
#       158    0.000    0.000    0.000    0.000 ast.py:211(iter_child_nodes)
#       297    0.000    0.000    0.000    0.000 byteflow.py:1570(get_inst)
#       369    0.000    0.000    0.000    0.000 models.py:532(get_value_type)
#         6    0.000    0.000    0.000    0.000 templates.py:189(fold_arguments)
#        56    0.000    0.000    0.000    0.000 typeinfer.py:667(_add_refine_map)
#         4    0.000    0.000    0.003    0.001 codegen.py:767(_finalize_dynamic_globals)
#       4/1    0.000    0.000    0.721    0.721 compiler.py:478(_compile_core)
#       103    0.000    0.000    0.000    0.000 ir.py:908(__init__)
#       313    0.000    0.000    0.000    0.000 common.py:9(_decode_string)
#       106    0.000    0.000    0.000    0.000 ir.py:1090(__init__)
#       114    0.000    0.000    0.001    0.000 context.py:268(core)
#       304    0.000    0.000    0.001    0.000 base.py:372(_insert_getattr_defn)
#   128/116    0.000    0.000    0.004    0.000 ir_utils.py:1542(guard)
#       454    0.000    0.000    0.000    0.000 ir.py:1102(__str__)
#       101    0.000    0.000    0.000    0.000 _utils.py:76(<listcomp>)
#        73    0.000    0.000    0.000    0.000 typeinfer.py:916(__setitem__)
#       105    0.000    0.000    0.001    0.000 event.py:436(on_exit)
#         4    0.000    0.000    0.000    0.000 analysis.py:580(rewrite_semantic_constants)
#       128    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        76    0.000    0.000    0.000    0.000 types.py:452(_to_string)
#       108    0.000    0.000    0.000    0.000 numpy_support.py:394(<listcomp>)
#       361    0.000    0.000    0.000    0.000 abstract.py:115(__repr__)
#         8    0.000    0.000    0.000    0.000 passmanagers.py:46(dump_refprune_stats)
#        21    0.000    0.000    0.001    0.000 module.py:189(functions)
#        89    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       395    0.000    0.000    0.000    0.000 __init__.py:1677(isEnabledFor)
#        31    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        11    0.000    0.000    0.113    0.010 base.py:881(call_internal)
#        79    0.000    0.000    0.000    0.000 models.py:499(<listcomp>)
#        17    0.000    0.000    0.001    0.000 packer.py:115(assign_names)
#        93    0.000    0.000    0.000    0.000 bytecode.py:203(next)
#         8    0.000    0.000    0.000    0.000 ir_utils.py:551(remove_dels)
#       163    0.000    0.000    0.000    0.000 builder.py:173(_label_suffix)
#        20    0.000    0.000    0.001    0.000 npytypes.py:470(copy)
#        86    0.000    0.000    0.000    0.000 instructions.py:26(module)
#       110    0.000    0.000    0.000    0.000 contextlib.py:385(__init__)
#        50    0.000    0.000    0.000    0.000 utils.py:254(__init__)
#        62    0.000    0.000    0.001    0.000 models.py:135(contains_nrt_meminfo)
#        40    0.000    0.000    0.000    0.000 misc.py:61(literal)
#         4    0.000    0.000    0.001    0.000 config.py:135(update)
#       304    0.000    0.000    0.001    0.000 base.py:380(_insert_cast_defn)
#         4    0.000    0.000    0.004    0.001 compiler.py:413(__init__)
#        25    0.000    0.000    0.000    0.000 copy.py:66(copy)
#        50    0.000    0.000    0.001    0.000 passmanagers.py:738(finalize)
#       304    0.000    0.000    0.001    0.000 base.py:384(_insert_get_constant_defn)
#        19    0.000    0.000    0.048    0.003 module.py:233(__repr__)
#        12    0.000    0.000    0.000    0.000 ir_utils.py:1588(find_callname)
#        25    0.000    0.000    0.044    0.002 base.py:1186(__call__)
#         4    0.000    0.000    0.001    0.000 bytecode.py:226(__init__)
#        45    0.000    0.000    0.002    0.000 arrayobj.py:54(mark_positive)
#       150    0.000    0.000    0.002    0.000 compiler_lock.py:19(__enter__)
#         4    0.000    0.000    0.000    0.000 targetconfig.py:272(_make_compression_dictionary)
#       225    0.000    0.000    0.000    0.000 analysis.py:138(<genexpr>)
#        56    0.000    0.000    0.000    0.000 typeinfer.py:515(<listcomp>)
#        18    0.000    0.000    0.002    0.000 templates.py:698(_get_impl)
#       304    0.000    0.000    0.001    0.000 base.py:376(_insert_setattr_defn)
#        32    0.000    0.000    0.001    0.000 lowering.py:1578(_lit_or_omitted)
#       107    0.000    0.000    0.002    0.000 instructions.py:175(descr)
#        15    0.000    0.000    0.000    0.000 byteflow.py:1459(__init__)
#       387    0.000    0.000    0.000    0.000 ast.py:199(iter_fields)
#       104    0.000    0.000    0.000    0.000 ir.py:194(with_lineno)
#       5/1    0.000    0.000    0.723    0.723 dispatcher.py:915(compile)
#        19    0.000    0.000    0.000    0.000 module.py:7(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Compress' objects}
#       416    0.000    0.000    0.000    0.000 compiler_machinery.py:41(name)
#       462    0.000    0.000    0.000    0.000 models.py:233(get_value_type)
#        25    0.000    0.000    0.002    0.000 base.py:1209(__call__)
#        37    0.000    0.000    0.001    0.000 typed_passes.py:698(_get_callable_info)
#        24    0.000    0.000    0.000    0.000 typed_passes.py:757(select_template)
#         4    0.000    0.000    0.000    0.000 typed_passes.py:905(_strip_phi_nodes)
#       397    0.000    0.000    0.000    0.000 bytecode.py:268(__getitem__)
#       161    0.000    0.000    0.000    0.000 templates.py:269(__init__)
#      42/2    0.000    0.000    0.000    0.000 arrayprint.py:789(recurser)
#         6    0.000    0.000    0.041    0.007 values.py:999(descr_body)
#        28    0.000    0.000    0.000    0.000 builder.py:539(not_)
#        37    0.000    0.000    0.000    0.000 builder.py:629(select)
#        40    0.000    0.000    0.000    0.000 arrayprint.py:1018(__call__)
#        58    0.000    0.000    0.000    0.000 re.py:287(_compile)
#       110    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#        27    0.000    0.000    0.000    0.000 cgutils.py:44(make_bytearray)
#        56    0.000    0.000    0.021    0.000 typeinfer.py:1519(resolve_call)
#       4/1    0.000    0.000    1.127    1.127 {built-in method builtins.exec}
#     64/56    0.000    0.000    0.020    0.000 context.py:189(resolve_function_type)
#        10    0.000    0.000    0.001    0.000 targets.py:9(get_process_triple)
#        18    0.000    0.000    0.000    0.000 transforms.py:293(has_multiple_backedges)
#        26    0.000    0.000    0.001    0.000 itanium_mangler.py:107(mangle_identifier)
#        25    0.000    0.000    0.043    0.002 base.py:1215(wrapper)
#         4    0.000    0.000    0.000    0.000 typed_passes.py:569(run_pass)
#         4    0.000    0.000    0.001    0.000 typeinfer.py:1118(unify)
#         4    0.000    0.000    0.003    0.001 codegen.py:1013(scan_unresolved_symbols)
#       341    0.000    0.000    0.000    0.000 misc.py:170(key)
#         6    0.000    0.000    0.000    0.000 inspect.py:2889(_bind)
#        42    0.000    0.000    0.001    0.000 cgutils.py:435(add_global_variable)
#        93    0.000    0.000    0.000    0.000 templates.py:128(as_function)
#        58    0.000    0.000    0.000    0.000 numpy_support.py:332(_ufunc_loop_sig)
#        13    0.000    0.000    0.102    0.008 callconv.py:767(return_status_propagate)
#       151    0.000    0.000    0.000    0.000 ir.py:1297(append)
#       100    0.000    0.000    0.000    0.000 controlflow.py:133(set_entry_point)
#        89    0.000    0.000    0.000    0.000 bytecode.py:141(_unpack_opargs)
#        18    0.000    0.000    0.000    0.000 typeinfer.py:217(__call__)
#        18    0.000    0.000    0.004    0.000 templates.py:607(generic)
#        91    0.000    0.000    0.000    0.000 ssa.py:190(_run_ssa_block_pass)
#       212    0.000    0.000    0.000    0.000 cpu_options.py:180(encode)
#        58    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 targetconfig.py:257(_summary_args)
#        39    0.000    0.000    0.001    0.000 builder.py:858(ret)
#       620    0.000    0.000    0.000    0.000 ir.py:275(__contains__)
#        29    0.000    0.000    0.000    0.000 inspect.py:493(unwrap)
#       162    0.000    0.000    0.000    0.000 context.py:52(__getitem__)
#       174    0.000    0.000    0.000    0.000 lowering.py:325(debug_print)
# ...
#         8    0.000    0.000    0.000    0.000 inline_closurecall.py:351(<listcomp>)
#         4    0.000    0.000    0.000    0.000 utils.py:437(__len__)
#         1    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#         1    0.000    0.000    0.000    0.000 interpreter.py:2544(<listcomp>)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1210(get_array_memory_extents)
#         3    0.000    0.000    0.000    0.000 interpreter.py:2686(op_BINARY_TRUE_DIVIDE)
#        10    0.000    0.000    0.000    0.000 cgutils.py:640(<lambda>)
#         4    0.000    0.000    0.000    0.000 codegen.py:542(recorded_timings)
#         3    0.000    0.000    0.000    0.000 typeinfer.py:708(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1297(_unaryop)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:11(__init__)
#         1    0.000    0.000    0.000    0.000 options.py:30(parse_as_flags)
#         8    0.000    0.000    0.000    0.000 abstract.py:222(is_internal)
#         1    0.000    0.000    0.000    0.000 base.py:482(pack_value)
#         4    0.000    0.000    0.000    0.000 npyimpl.py:328(_pack_output_values)
#         4    0.000    0.000    0.000    0.000 nrt.py:48(_init_guard)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:550(_is_array_not_precise)
#         1    0.000    0.000    0.000    0.000 targets.py:159(get_pointee_abi_alignment)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         4    0.000    0.000    0.000    0.000 funcdesc.py:79(lookup_globals)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:233(decref)
#         4    0.000    0.000    0.000    0.000 functools.py:428(_unwrap_partial)
#         4    0.000    0.000    0.000    0.000 parfor.py:746(has_setup)
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#         3    0.000    0.000    0.000    0.000 models.py:343(inner_models)
#         9    0.000    0.000    0.000    0.000 bytecode.py:229(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lowering.py:1352(<listcomp>)
#         7    0.000    0.000    0.000    0.000 array_exprs.py:362(<lambda>)
#        12    0.000    0.000    0.000    0.000 byteflow.py:1518(instructions)
#         1    0.000    0.000    0.000    0.000 mathimpl.py:92(negate_real)
#         4    0.000    0.000    0.000    0.000 codegen.py:1045(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:281(_compilation_chain_init_hook)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:129(<listcomp>)
#         2    0.000    0.000    0.000    0.000 abstract.py:433(_literal_init)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#         4    0.000    0.000    0.000    0.000 cpu_options.py:147(is_never_inline)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:729(get_index_bounds)
#         4    0.000    0.000    0.000    0.000 common.py:32(yield_type)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1347(<listcomp>)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1114(op_ROT_THREE)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hex}
#         8    0.000    0.000    0.000    0.000 controlflow.py:285(dead_nodes)
#         2    0.000    0.000    0.000    0.000 pythonapi.py:100(__init__)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1011(op_STORE_SUBSCR)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1029(<listcomp>)
#         5    0.000    0.000    0.000    0.000 ir.py:1038(infer_constant)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         8    0.000    0.000    0.000    0.000 codegen.py:553(name)
#         1    0.000    0.000    0.001    0.001 callwrapper.py:66(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:927(cb_llvm)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:714(__init__)
#         8    0.000    0.000    0.000    0.000 analysis.py:487(<listcomp>)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1099(op_DUP_TOP_TWO)
#         4    0.000    0.000    0.000    0.000 npyimpl.py:375(<listcomp>)
#         4    0.000    0.000    0.000    0.000 context.py:642(keyfunc)
#         2    0.000    0.000    0.000    0.000 imputils.py:280(yield_)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:1192(borrow_none)
#         2    0.000    0.000    0.000    0.000 cgutils.py:789(<listcomp>)
#         4    0.000    0.000    0.000    0.000 ssa.py:37(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#         1    0.000    0.000    0.723    0.723 dispatcher.py:124(compile)
#         1    0.000    0.000    0.005    0.005 pythonapi.py:1433(from_native_return)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:966(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cgutils.py:464(if_likely)
#         4    0.000    0.000    0.000    0.000 transforms.py:749(consolidate_multi_exit_withs)
#         3    0.000    0.000    0.000    0.000 array_exprs.py:365(<listcomp>)
#         4    0.000    0.000    0.000    0.000 common.py:21(iterator_type)
#         8    0.000    0.000    0.000    0.000 inline_closurecall.py:320(check)
#         4    0.000    0.000    0.000    0.000 typeinfer.py:1234(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 cpu.py:199(<listcomp>)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:72(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 ssa.py:224(on_other)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:200(get_env_manager)
#         2    0.000    0.000    0.000    0.000 types.py:471(<listcomp>)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1446(op_LOAD_METHOD)
#         1    0.000    0.000    0.000    0.000 context.py:30(__init__)
#         1    0.000    0.000    0.000    0.000 cpu.py:262(get_ufunc_info)
#         1    0.000    0.000    0.000    0.000 interpreter.py:2716(op_INPLACE_ADD)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:341(<listcomp>)
#         1    0.000    0.000    0.000    0.000 array_exprs.py:15(_is_ufunc)
#         6    0.000    0.000    0.000    0.000 imputils.py:425(impl_ret_new_ref)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:758(_callback_add_llvm_timer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1221(extents_may_overlap)
#         8    0.000    0.000    0.000    0.000 typeinfer.py:1754(propagate_finished)
#        12    0.000    0.000    0.000    0.000 byteflow.py:1544(blockstack_initial)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1344(<listcomp>)
#         2    0.000    0.000    0.000    0.000 models.py:614(from_argument)
#         1    0.000    0.000    0.000    0.000 base.py:37(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:81(RLock)
#         2    0.000    0.000    0.000    0.000 imputils.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 lowering.py:1350(<listcomp>)
#         1    0.000    0.000    0.000    0.000 npyimpl.py:481(<listcomp>)
#         1    0.000    0.000    0.000    0.000 registry.py:50(typing_context)
#         1    0.000    0.000    0.000    0.000 interpreter.py:2916(op_POP_JUMP_IF_FALSE)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1080(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:1055(<listcomp>)
#         4    0.000    0.000    0.000    0.000 npyimpl.py:390(<listcomp>)
#        12    0.000    0.000    0.000    0.000 byteflow.py:1535(outgoing_phis)
#         8    0.000    0.000    0.000    0.000 typeinfer.py:1751(propagate_started)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:108(__init__)
#         4    0.000    0.000    0.000    0.000 callconv.py:370(_make_call_helper)
#         9    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 codegen.py:1082(is_symbol_defined)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:438(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:518(get_constant_undef)
#         4    0.000    0.000    0.000    0.000 npyimpl.py:389(<listcomp>)
#         6    0.000    0.000    0.000    0.000 types.py:357(__len__)
#         4    0.000    0.000    0.000    0.000 abstract.py:439(literal_value)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:420(__init__)
#         2    0.000    0.000    0.000    0.000 funcdesc.py:108(llvm_func_name)
#         2    0.000    0.000    0.000    0.000 byteflow.py:290(_guard_with_as)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 arrayobj.py:178(<listcomp>)
#         4    0.000    0.000    0.000    0.000 lowering.py:79(init)
#         5    0.000    0.000    0.000    0.000 debuginfo.py:66(mark_variable)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:139(store_item)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1143(<listcomp>)
#         4    0.000    0.000    0.000    0.000 inline_closurecall.py:809(_debug_dump)
#         1    0.000    0.000    0.000    0.000 transforms.py:290(new_block_id)
#         4    0.000    0.000    0.000    0.000 transforms.py:589(<listcomp>)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1084(<listcomp>)
#         4    0.000    0.000    0.000    0.000 debuginfo.py:73(mark_subprogram)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1348(<listcomp>)
#         4    0.000    0.000    0.000    0.000 errors.py:508(__enter__)
#         2    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 npytypes.py:517(box_type)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 byteflow.py:1600(get_tos)
#         6    0.000    0.000    0.000    0.000 event.py:286(duration)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1603(peek)
#         5    0.000    0.000    0.000    0.000 errors.py:193(code)
#         2    0.000    0.000    0.000    0.000 npyimpl.py:78(create_iter_indices)
#         2    0.000    0.000    0.000    0.000 controlflow.py:703(<lambda>)
#         1    0.000    0.000    0.000    0.000 typeinfer.py:770(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 debuginfo.py:63(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#         3    0.000    0.000    0.000    0.000 base.py:1111(get_preferred_array_alignment)
#         1    0.000    0.000    0.000    0.000 array_exprs.py:133(_translate_expr)
#         4    0.000    0.000    0.000    0.000 functions.py:505(key)
#         4    0.000    0.000    0.000    0.000 dispatcher.py:108(normal_handler)
#         1    0.000    0.000    0.000    0.000 base.py:1059(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lowering.py:1351(<listcomp>)
#         4    0.000    0.000    0.000    0.000 compiler_machinery.py:256(finalized)
#         2    0.000    0.000    0.000    0.000 npyimpl.py:81(load_data)
#         4    0.000    0.000    0.000    0.000 bytecode.py:197(__iter__)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:159(normalize_index)
#         1    0.000    0.000    0.000    0.000 models.py:547(get_return_type)
#         5    0.000    0.000    0.000    0.000 errors.py:199(filename)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:723(get_size)
#         1    0.000    0.000    0.000    0.000 ir.py:1305(clear)
#         6    0.000    0.000    0.000    0.000 models.py:168(get_argument_type)
#         3    0.000    0.000    0.000    0.000 values.py:957(basic_blocks)
#         4    0.000    0.000    0.000    0.000 typeinfer.py:1757(unify_finished)
#         1    0.000    0.000    0.000    0.000 context.py:53(allocate)
#         5    0.000    0.000    0.000    0.000 models.py:236(as_data)
#         4    0.000    0.000    0.000    0.000 models.py:502(inner_models)
#         4    0.000    0.000    0.000    0.000 transforms.py:616(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 typeinfer.py:234(__init__)
#         1    0.000    0.000    0.000    0.000 codegen.py:620(enable_object_caching)
#         3    0.000    0.000    0.000    0.000 models.py:717(inner_models)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1350(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cgutils.py:202(_getpointer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1346(<listcomp>)
#         3    0.000    0.000    0.000    0.000 models.py:242(as_return)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:754(_callback_add_compiler_timer)
#         4    0.000    0.000    0.000    0.000 interpreter.py:1844(op_NOP)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:733(loop_head)
#         4    0.000    0.000    0.000    0.000 debuginfo.py:79(finalize)
#         1    0.000    0.000    0.000    0.000 funcdesc.py:126(llvm_cfunc_wrapper_name)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2670(_amax_dispatcher)
#         2    0.000    0.000    0.000    0.000 npyimpl.py:47(as_values)
#         1    0.000    0.000    0.000    0.000 1898012171.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:898(_none_or_positive_arg)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:166(_get_implementation)
#         2    0.000    0.000    0.000    0.000 types.py:449(__len__)
#         1    0.000    0.000    0.000    0.000 models.py:538(get_data_type)
#         1    0.000    0.000    0.000    0.000 registry.py:39(target_context)
#         1    0.000    0.000    0.000    0.000 base.py:329(nonconst_module_attrs)
#         2    0.000    0.000    0.000    0.000 transforms.py:312(replace)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2795(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 values.py:867(_expand)
#         2    0.000    0.000    0.000    0.000 inline_closurecall.py:127(<lambda>)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:682(get_shape)
#         2    0.000    0.000    0.000    0.000 npyimpl.py:44(update_indices)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1733(<listcomp>)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:736(loop_tail)
#         1    0.000    0.000    0.000    0.000 numbers.py:1217(bool_as_bool)
#         1    0.000    0.000    0.000    0.000 options.py:15(<lambda>)
#         1    0.000    0.000    0.000    0.000 codegen.py:546(codegen)
#         2    0.000    0.000    0.000    0.000 models.py:493(from_return)
#         1    0.000    0.000    0.000    0.000 caching.py:85(save_overload)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:169(_customize_flags)
#         2    0.000    0.000    0.000    0.000 context.py:148(init)
#         2    0.000    0.000    0.000    0.000 models.py:171(as_argument)
#         1    0.000    0.000    0.000    0.000 caching.py:82(load_overload)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:726(get_shape)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:1041(get_shape)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.not_}
#         1    0.000    0.000    0.000    0.000 models.py:490(as_return)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:720(prepare)
#         1    0.000    0.000    0.000    0.000 typeinfer.py:794(get_call_signature)
#         1    0.000    0.000    0.000    0.000 __init__.py:554(__missing__)

# %%
fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=frames, interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# This is faster than pure Python, but often only marginally so. In this case, I find a factor of ~4 faster. That's not too bad given that all we had to do was add an `@jit`

# %% [markdown]
# ## Optimization with cython
#
# We finally get the opportunity to use Cython, which we discussed in lecture a couple of weeks back. Cython is a "C-like" superset of the Python language that "converts" Python code  to C and then compiles the code to improve runtime performance.
# * This means that any python program is also a cython program.
# * You can give cython directives to help do the conversion faster.
#
# There are a number of directives, but the most important are data directives. You define the type of the data:
# * cdef int -> int in c
# * cdef float or cdef double -> float or double in c
# * cdef int/float/double [:] or [:,:] as arrays -> int, float, double * or **
#
# This may not seem like it does much, but it allows Cython to compile things in the C and use its much faster native data types.
#
# We use Cython in Jupyter with magic commands.

# %%
# load Cython
# %load_ext cython

# %%
# %%cython -a --verbose
# import numpy as np
# from cpython cimport array
# import array
# import math
#
# def cython_Nbody_derivatives(pos, vel, M):
#     cdef int N_bodies = M.size
#     cdef int i = 0, j = 0
#     cdef double [:,:] p = pos
#     cdef double [:] mass = M
#     rhat = np.zeros(3)
#     cdef double [:] rh = rhat
#     cdef double r = 0., r2 = 0.
#     dpdt = vel
#     dvdt_arr = np.zeros(vel.shape)
#     cdef double [:,:] dvdt = dvdt_arr
#     for i in range(N_bodies):
#         for j in range(N_bodies):
#             if i == j:
#                 continue
#             r2 = 0.
#             for k in range(3) :
#                 r2 += p[j,k]*p[j,k] + p[i,k]*p[i,k]
#             r = math.sqrt(r2)
#             for k in range(3) :
#                 rh[k] = (p[j,k] - p[i,k])/r
#                 dvdt[i,k] += -mass[j]/(r*r)*rh[k]
#
#     return dpdt, dvdt_arr
#
# # Note that this might provide a very long list of compilation warnings
# Out:
# [1/1] Cythonizing /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.pyx
# building '_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381' extension
# clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/core/include -I/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8 -c /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c -o /Users/swd8g/.cache/ipython/cython/Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.o
# clang -bundle -undefined dynamic_lookup -L/usr/local/opt/readline/lib -L/usr/local/opt/readline/lib -L/Users/swd8g/.pyenv/versions/3.8.0/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/readline/lib -L/Users/swd8g/.pyenv/versions/3.8.0/lib /Users/swd8g/.cache/ipython/cython/Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.o -o /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.cpython-38-darwin.so
# Content of stderr:
# In file included from /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:33:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:25:
# In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:64:
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:93:16: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         unsigned char   *_base;
#                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:93:16: note: insert '_Nullable' if the pointer may be null
#         unsigned char   *_base;
#                         ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:93:16: note: insert '_Nonnull' if the pointer should never be null
#         unsigned char   *_base;
#                         ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: note: insert '_Nullable' if the pointer may be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: note: insert '_Nonnull' if the pointer should never be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: note: insert '_Nullable' if the pointer may be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#                                                    _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: note: insert '_Nonnull' if the pointer should never be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#                                                    _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: note: insert '_Nullable' if the pointer may be null
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: note: insert '_Nonnull' if the pointer should never be null
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32: note: insert '_Nullable' if the pointer may be null
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32: note: insert '_Nonnull' if the pointer should never be null
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:46: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _write)(void *, const char *, int);
#                                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:46: note: insert '_Nullable' if the pointer may be null
#         int     (* _Nullable _write)(void *, const char *, int);
#                                                         ^
#                                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:46: note: insert '_Nonnull' if the pointer should never be null
#         int     (* _Nullable _write)(void *, const char *, int);
#                                                         ^
#                                                          _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:144:18: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#         struct __sFILEX *_extra; /* additions to FILE to not break ABI */
#                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:144:18: note: insert '_Nullable' if the pointer may be null
#         struct __sFILEX *_extra; /* additions to FILE to not break ABI */
#                         ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:144:18: note: insert '_Nonnull' if the pointer should never be null
#         struct __sFILEX *_extra; /* additions to FILE to not break ABI */
#                         ^
#                           _Nonnull
# In file included from /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:33:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:25:
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:67:13: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# extern FILE *__stdinp;
#             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:67:13: note: insert '_Nullable' if the pointer may be null
# extern FILE *__stdinp;
#             ^
#               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:67:13: note: insert '_Nonnull' if the pointer should never be null
# extern FILE *__stdinp;
#             ^
#               _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:41: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:41: note: insert '_Nullable' if the pointer may be null
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
#                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:41: note: insert '_Nonnull' if the pointer should never be null
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
#                                          _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:55: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#                  int (* _Nullable)(void *, const char *, int),
#                                                       ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:55: note: insert '_Nullable' if the pointer may be null
#                  int (* _Nullable)(void *, const char *, int),
#                                                       ^
#                                                        _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:55: note: insert '_Nonnull' if the pointer should never be null
#                  int (* _Nullable)(void *, const char *, int),
#                                                       ^
#                                                        _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: note: insert '_Nullable' if the pointer may be null
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
#                                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: note: insert '_Nonnull' if the pointer should never be null
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
#                                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#                  int (* _Nullable)(void *));
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41: note: insert '_Nullable' if the pointer may be null
#                  int (* _Nullable)(void *));
#                                         ^
#                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41: note: insert '_Nonnull' if the pointer should never be null
#                  int (* _Nullable)(void *));
#                                         ^
#                                          _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384:6: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# FILE    *funopen(const void *,
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384:6: note: insert '_Nullable' if the pointer may be null
# FILE    *funopen(const void *,
#         ^
#           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384:6: note: insert '_Nonnull' if the pointer should never be null
# FILE    *funopen(const void *,
#         ^
#           _Nonnull
# In file included from /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:33:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:34:
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:134:25: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# double   atof(const char *);
#                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:134:25: note: insert '_Nullable' if the pointer may be null
# double   atof(const char *);
#                          ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:134:25: note: insert '_Nonnull' if the pointer should never be null
# double   atof(const char *);
#                          ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:135:22: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# int      atoi(const char *);
#                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:135:22: note: insert '_Nullable' if the pointer may be null
# int      atoi(const char *);
#                          ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:135:22: note: insert '_Nonnull' if the pointer should never be null
# int      atoi(const char *);
#                          ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:136:23: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# long     atol(const char *);
#                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:136:23: note: insert '_Nullable' if the pointer may be null
# long     atol(const char *);
#                          ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:136:23: note: insert '_Nonnull' if the pointer should never be null
# long     atol(const char *);
#                          ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:139:20: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          atoll(const char *);
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:139:20: note: insert '_Nullable' if the pointer may be null
#          atoll(const char *);
#                           ^
#                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:139:20: note: insert '_Nonnull' if the pointer should never be null
#          atoll(const char *);
#                           ^
#                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:26: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:26: note: insert '_Nullable' if the pointer may be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                             ^
#                               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:26: note: insert '_Nonnull' if the pointer should never be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                             ^
#                               _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:45: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:45: note: insert '_Nullable' if the pointer may be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:45: note: insert '_Nonnull' if the pointer should never be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                  ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: note: insert '_Nullable' if the pointer may be null
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                  ^
#                                                                   _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: note: insert '_Nonnull' if the pointer should never be null
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                  ^
#                                                                   _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:73: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:73: note: insert '_Nullable' if the pointer may be null
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                                ^
#                                                                                 _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:73: note: insert '_Nonnull' if the pointer should never be null
#             size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                                ^
#                                                                                 _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:6: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:6: note: insert '_Nullable' if the pointer may be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
#           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:6: note: insert '_Nonnull' if the pointer should never be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
#           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:25: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# char    *getenv(const char *);
#                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:25: note: insert '_Nullable' if the pointer may be null
# char    *getenv(const char *);
#                            ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:25: note: insert '_Nonnull' if the pointer should never be null
# char    *getenv(const char *);
#                            ^
#                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:6: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# char    *getenv(const char *);
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:6: note: insert '_Nullable' if the pointer may be null
# char    *getenv(const char *);
#         ^
#           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:6: note: insert '_Nonnull' if the pointer should never be null
# char    *getenv(const char *);
#         ^
#           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:156:23: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# int      mblen(const char *__s, size_t __n);
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:156:23: note: insert '_Nullable' if the pointer may be null
# int      mblen(const char *__s, size_t __n);
#                           ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:156:23: note: insert '_Nonnull' if the pointer should never be null
# int      mblen(const char *__s, size_t __n);
#                           ^
#                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:26: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:26: note: insert '_Nullable' if the pointer may be null
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                           ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:26: note: insert '_Nonnull' if the pointer should never be null
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                           ^
#                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:52: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                                                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:52: note: insert '_Nullable' if the pointer may be null
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                                                     ^
#                                                       _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:157:52: note: insert '_Nonnull' if the pointer should never be null
# size_t   mbstowcs(wchar_t * __restrict , const char * __restrict, size_t);
#                                                     ^
#                                                       _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:21: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:21: note: insert '_Nullable' if the pointer may be null
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                         ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:21: note: insert '_Nonnull' if the pointer should never be null
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                         ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:46: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                                                  ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:46: note: insert '_Nullable' if the pointer may be null
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                                                  ^
#                                                    _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:158:46: note: insert '_Nonnull' if the pointer should never be null
# int      mbtowc(wchar_t * __restrict, const char * __restrict, size_t);
#                                                  ^
#                                                    _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:160:18: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# void     qsort(void *__base, size_t __nel, size_t __width,
#                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:160:18: note: insert '_Nullable' if the pointer may be null
# void     qsort(void *__base, size_t __nel, size_t __width,
#                     ^
#                       _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:160:18: note: insert '_Nonnull' if the pointer should never be null
# void     qsort(void *__base, size_t __nel, size_t __width,
#                     ^
#                       _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:43: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                  ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:43: note: insert '_Nullable' if the pointer may be null
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                  ^
#                                                   _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:43: note: insert '_Nonnull' if the pointer should never be null
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                  ^
#                                                   _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:57: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:57: note: insert '_Nullable' if the pointer may be null
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                                ^
#                                                                 _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:161:57: note: insert '_Nonnull' if the pointer should never be null
#             int (* _Nonnull __compar)(const void *, const void *));
#                                                                ^
#                                                                 _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:27: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:27: note: insert '_Nullable' if the pointer may be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                            ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:27: note: insert '_Nonnull' if the pointer should never be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                            ^
#                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:35: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                    ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:35: note: insert '_Nullable' if the pointer may be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                    ^
#                                     _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:35: note: insert '_Nonnull' if the pointer should never be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                    ^
#                                     _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:36: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:36: note: insert '_Nullable' if the pointer may be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                     ^
#                                      _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:165:36: note: insert '_Nonnull' if the pointer should never be null
# double   strtod(const char *, char **) __DARWIN_ALIAS(strtod);
#                                     ^
#                                      _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:26: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:26: note: insert '_Nullable' if the pointer may be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                            ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:26: note: insert '_Nonnull' if the pointer should never be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                            ^
#                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:34: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                    ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:34: note: insert '_Nullable' if the pointer may be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                    ^
#                                     _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:34: note: insert '_Nonnull' if the pointer should never be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                    ^
#                                     _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:35: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:35: note: insert '_Nullable' if the pointer may be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                     ^
#                                      _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:166:35: note: insert '_Nonnull' if the pointer should never be null
# float    strtof(const char *, char **) __DARWIN_ALIAS(strtof);
#                                     ^
#                                      _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:25: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# long     strtol(const char *__str, char **__endptr, int __base);
#                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:25: note: insert '_Nullable' if the pointer may be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                            ^
#                              _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:25: note: insert '_Nonnull' if the pointer should never be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                            ^
#                              _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:38: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# long     strtol(const char *__str, char **__endptr, int __base);
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:38: note: insert '_Nullable' if the pointer may be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                                         ^
#                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:38: note: insert '_Nonnull' if the pointer should never be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                                         ^
#                                          _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:39: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# long     strtol(const char *__str, char **__endptr, int __base);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:39: note: insert '_Nullable' if the pointer may be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                                          ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:167:39: note: insert '_Nonnull' if the pointer should never be null
# long     strtol(const char *__str, char **__endptr, int __base);
#                                          ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:22: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtold(const char *, char **);
#                             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:22: note: insert '_Nullable' if the pointer may be null
#          strtold(const char *, char **);
#                             ^
#                              _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:22: note: insert '_Nonnull' if the pointer should never be null
#          strtold(const char *, char **);
#                             ^
#                              _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:30: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtold(const char *, char **);
#                                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:30: note: insert '_Nullable' if the pointer may be null
#          strtold(const char *, char **);
#                                     ^
#                                      _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:30: note: insert '_Nonnull' if the pointer should never be null
#          strtold(const char *, char **);
#                                     ^
#                                      _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:31: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtold(const char *, char **);
#                                      ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:31: note: insert '_Nullable' if the pointer may be null
#          strtold(const char *, char **);
#                                      ^
#                                       _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:169:31: note: insert '_Nonnull' if the pointer should never be null
#          strtold(const char *, char **);
#                                      ^
#                                       _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:22: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoll(const char *__str, char **__endptr, int __base);
#                             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:22: note: insert '_Nullable' if the pointer may be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                             ^
#                               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:22: note: insert '_Nonnull' if the pointer should never be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                             ^
#                               _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:35: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoll(const char *__str, char **__endptr, int __base);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:35: note: insert '_Nullable' if the pointer may be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                                          ^
#                                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:35: note: insert '_Nonnull' if the pointer should never be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                                          ^
#                                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:36: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoll(const char *__str, char **__endptr, int __base);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:36: note: insert '_Nullable' if the pointer may be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:172:36: note: insert '_Nonnull' if the pointer should never be null
#          strtoll(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:22: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoul(const char *__str, char **__endptr, int __base);
#                             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:22: note: insert '_Nullable' if the pointer may be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                             ^
#                               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:22: note: insert '_Nonnull' if the pointer should never be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                             ^
#                               _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:35: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoul(const char *__str, char **__endptr, int __base);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:35: note: insert '_Nullable' if the pointer may be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                                          ^
#                                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:35: note: insert '_Nonnull' if the pointer should never be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                                          ^
#                                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:36: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoul(const char *__str, char **__endptr, int __base);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:36: note: insert '_Nullable' if the pointer may be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:175:36: note: insert '_Nonnull' if the pointer should never be null
#          strtoul(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:23: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoull(const char *__str, char **__endptr, int __base);
#                              ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:23: note: insert '_Nullable' if the pointer may be null
#          strtoull(const char *__str, char **__endptr, int __base);
#                              ^
#                                _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:23: note: insert '_Nonnull' if the pointer should never be null
#          strtoull(const char *__str, char **__endptr, int __base);
#                              ^
#                                _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:36: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
#          strtoull(const char *__str, char **__endptr, int __base);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:36: note: insert '_Nullable' if the pointer may be null
#          strtoull(const char *__str, char **__endptr, int __base);
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:36: note: insert '_Nonnull' if the pointer should never be null
#          strtoull(const char *__str, char **__endptr, int __base);
#                                           ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:178:37: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# ...
#          strtouq(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:354:36: note: insert '_Nonnull' if the pointer should never be null
#          strtouq(const char *__str, char **__endptr, int __base);
#                                           ^
#                                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:356:13: warning: pointer is missing a nullability type specifier (_Nonnull, _Nullable, or _Null_unspecified) [-Wnullability-completeness]
# extern char *suboptarg;         /* getsubopt(3) external variable */
#             ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:356:13: note: insert '_Nullable' if the pointer may be null
# extern char *suboptarg;         /* getsubopt(3) external variable */
#             ^
#               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:356:13: note: insert '_Nonnull' if the pointer should never be null
# extern char *suboptarg;         /* getsubopt(3) external variable */
#             ^
#               _Nonnull
# In file included from /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:33:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:121:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/genobject.h:11:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pystate.h:10:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pythread.h:120:
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:331:6: warning: macro expansion producing 'defined' has undefined behavior [-Wexpansion-to-defined]
# #if !_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT
#      ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:200:2: note: expanded from macro '_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT'
#         defined(SWIFT_CLASS_EXTRA) && (!defined(SWIFT_SDK_OVERLAY_PTHREAD_EPOCH) || (SWIFT_SDK_OVERLAY_PTHREAD_EPOCH < 1))
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:331:6: warning: macro expansion producing 'defined' has undefined behavior [-Wexpansion-to-defined]
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:200:34: note: expanded from macro '_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT'
#         defined(SWIFT_CLASS_EXTRA) && (!defined(SWIFT_SDK_OVERLAY_PTHREAD_EPOCH) || (SWIFT_SDK_OVERLAY_PTHREAD_EPOCH < 1))
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:540:6: warning: macro expansion producing 'defined' has undefined behavior [-Wexpansion-to-defined]
# #if !_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT
#      ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:200:2: note: expanded from macro '_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT'
#         defined(SWIFT_CLASS_EXTRA) && (!defined(SWIFT_SDK_OVERLAY_PTHREAD_EPOCH) || (SWIFT_SDK_OVERLAY_PTHREAD_EPOCH < 1))
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:540:6: warning: macro expansion producing 'defined' has undefined behavior [-Wexpansion-to-defined]
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/pthread.h:200:34: note: expanded from macro '_PTHREAD_SWIFT_IMPORTER_NULLABILITY_COMPAT'
#         defined(SWIFT_CLASS_EXTRA) && (!defined(SWIFT_SDK_OVERLAY_PTHREAD_EPOCH) || (SWIFT_SDK_OVERLAY_PTHREAD_EPOCH < 1))
#                                         ^
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:19772:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#   0, /*tp_print*/
#   ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
# #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                      ^
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:19942:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#   0, /*tp_print*/
#   ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
# #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                      ^
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:20285:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#   0, /*tp_print*/
#   ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
# #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                      ^
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:20455:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#   0, /*tp_print*/
#   ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
# #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                      ^
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:22957:76: warning: code will never be executed [-Wunreachable-code]
#         if (__Pyx_PyTuple_SET_ITEM(argstuple, (Py_ssize_t)i, args[i]) < 0) goto bad;
#                                                                            ^~~~~~~~
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:22957:73: note: silence by adding parentheses to mark code as explicitly dead
#         if (__Pyx_PyTuple_SET_ITEM(argstuple, (Py_ssize_t)i, args[i]) < 0) goto bad;
#                                                                         ^
#                                                                         /* DISABLES CODE */ ( )
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:23993:26: warning: code will never be executed [-Wunreachable-code]
#                 module = PyImport_ImportModuleLevelObject(
#                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /Users/swd8g/.cache/ipython/cython/_cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.c:26241:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#     0,
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#     ^
# /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
# #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                      ^
# 201 warnings generated.
# <!DOCTYPE html>
# <!-- Generated by Cython 3.0.8 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_c8e4fa243692cd1563d97df90530e384aa652381.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { color: #000000; margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.scor

# %% [markdown]
# The bottom of the output (after any compiler warnings) should looks something like this
# ![figure1](cython.png)
#
# You can see the C code that is replacing the Python by clicking on the yellow lines.

# %%
def cython_derivs(pos,vel) :
    return cython_Nbody_derivatives(pos,vel,M)
    
# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, cython_derivs)
# Out:
#          3207 function calls in 0.077 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2000    0.058    0.000    0.058    0.000 4037453494.py:1(cython_derivs)
#         1    0.017    0.017    0.077    0.077 283640628.py:27(run_Nbody_rk2)
#       103    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1000    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.077    0.077 <string>:1(<module>)
#         1    0.000    0.000    0.077    0.077 {built-in method builtins.exec}
#       100    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# confirm it matches earlier results
fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=frames, interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# This is even slightly faster than our rewrite with NumPy.  Again, we had to significanly modify our function to be more C-like so this is not gained for free, but if performance really matters, than taking a little time to speed up the code by a factor of 100 may be worth the time it takes to do the coding.

# %% [markdown]
# ### Optimization with f2py
#
# We can also use Fortran to optimize, via `f2py`.  This is conceptually similar to Cython in that we are compiling code, but the code we are compiling is actual Fortran code. So we need to first generate the .f90 file using %%file.

# %%
# %%file nbody_derivatives.f90
# SUBROUTINE derivs(pos,vel,mass,dpdt,dvdt,n)
#     implicit none
#     integer, intent(IN) :: n
#     double precision, intent(IN), dimension(n,3):: pos, vel
#     double precision, intent(IN), dimension(n) :: mass
#     double precision, intent(OUT), dimension(n,3):: dpdt, dvdt
# !f2py intent(in) n
# !f2py intent(in) pos, vel, mass
# !f2py intent(out) dpdt, dvdt
# !f2py depend(n) mass
#     integer :: i, j
#     double precision, dimension(3) :: rhat,r
#     double precision :: r2
#
#     dpdt(:,:) = vel(:,:)
#     dvdt(:,:) = 0.
#     do i = 1,n
#         do j = 1,n
#             if( i .eq. j) then
#                 cycle
#             endif
#             r(:) = pos(j,:) - pos(i,:)
#             r2 = sum(r*r)
#             rhat = r/sqrt(r2)
#             dvdt(i,:) = dvdt(i,:)- mass(j)/(r2)*rhat(:)
#         enddo
#     enddo
#
#     return
# end subroutine derivs
# Out:
# Overwriting nbody_derivatives.f90

# %% [markdown]
# Now we compile it.  This step may be tricky as `f2py` needs to communicate with the Fortran compiler.  I found this step to be much easier on Linux than on my Mac.

# %%
# now compile it -- possibly a lengthy output with warnings
# !f2py -m nbody_derivatives -c nbody_derivatives.f90
# Out:
# running build
# running config_cc
# INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# INFO: build_src
# INFO: building extension "nbody_derivatives" sources
# INFO: f2py options: []
# INFO: f2py:> /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8
# Reading fortran codes...
# 	Reading file 'nbody_derivatives.f90' (format:free)
# Post-processing...
# 	Block: nbody_derivatives
# 			Block: derivs
# Post-processing (stage 2)...
# Building modules...
#     Building module "nbody_derivatives"...
#         Constructing wrapper function "derivs"...
#           dpdt,dvdt = derivs(pos,vel,mass,[n])
#     Wrote C/API module "nbody_derivatives" to file "/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c"
# INFO:   adding '/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.c' to sources.
# INFO:   adding '/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8' to include_dirs.
# copying /Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8
# copying /Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8
# INFO: build_src: building npy-pkg config files
# running build_ext
# INFO: customize UnixCCompiler
# INFO: customize UnixCCompiler using build_ext
# INFO: get_default_fcompiler: matching types: '['gnu95', 'nag', 'nagfor', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# INFO: customize Gnu95FCompiler
# INFO: Found executable /usr/local/bin/gfortran
# INFO: customize Gnu95FCompiler
# INFO: customize Gnu95FCompiler using build_ext
# INFO: building 'nbody_derivatives' extension
# INFO: compiling C sources
# INFO: C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -ftrapping-math
#
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders/88
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo
# creating /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8
# INFO: compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8 -I/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/core/include -I/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8 -c'
# INFO: clang: /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c
# INFO: clang: /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.c
# In file included from /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c:18:
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:25:
# In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:64:
# In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.c::932::
# 16In file included from :/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.h :7:
# warningIn file included from : /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h:25:
# In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:64:
#
#       /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.hpointer: 93is: 16missing:  a nullabilitywarning : type specifier (_Nonnull,
#        _Nullable,pointer  oris
#        missing_Null_unspecified)  a[-Wnullability-completeness] nullability
#  type specifier (_Nonnull, _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
#         unsigned char   *_base;
#                         ^        unsigned char   *_base;
#
#                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:93:16: note:
#       insert '_Nullable' if the pointer may be /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.hnull:93
# :16: note:
#       insert '_Nullable'        unsigned char   *_base;
# if                         ^the
#  pointer                           _Nullable may
#  be null
#         unsigned char   *_base;
#                         ^
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:93:16: note:
#       insert '_Nonnull' if the pointer should never /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.hbe: 93null:16
# : note:
#               unsigned char   *_base;insert
#  '_Nonnull'                        ^
# if the                          _Nonnull
# pointer should never be null
#         unsigned char   *_base;
#                         ^
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: warning: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138
# :      32pointer:  is missingwarning : a nullability
#        typepointer  specifieris  (_Nonnull,missing  _Nullable,a  ornullability
#        type_Null_unspecified)  specifier[-Wnullability-completeness] (_Nonnull,
#  _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: note: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h
# :      138insert: 32'_Nullable':  if thenote : pointer
# may       insertbe  '_Nullable'null if
#  the pointer may be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#                                            _Nullable
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:32: note: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:
#       insert32 :'_Nonnull'  if thenote : pointer
# should       insertnever  '_Nonnull'be  ifnull the
#  pointer should never be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                           ^
#                                            _Nonnull        int     (* _Nullable _read) (void *, char *, int);
#
#                                           ^
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138warning:: 40:
#       pointerwarning : is missing
#        apointer  nullabilityis  typemissing  specifiera  (_Nonnull,nullability  _Nullable,type  orspecifier
#        (_Nonnull,_Null_unspecified)  _Nullable,[-Wnullability-completeness] or
#
#       _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138note:: 40:
#        insert note'_Nullable':  if
#        theinsert  pointer'_Nullable'  mayif  bethe  nullpointer
# may be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#         int     (* _Nullable _read) (void *, char *, int);                                                   _Nullable
#
#                                                   ^
#                                                    _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138:40: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:138note:: 40:
#        insert note'_Nonnull':  if
#        theinsert  pointer'_Nonnull' if  the pointer shouldshould never be null
#  never be null
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#                                                    _Nonnull
#         int     (* _Nullable _read) (void *, char *, int);
#                                                   ^
#                                                    _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:warning139: :35:
#        pointer warningis:  missing
# a       pointernullability  istype  missingspecifier  a(_Nonnull,  nullability_Nullable,  typeor
# specifier       _Null_unspecified)(_Nonnull,  [-Wnullability-completeness]_Nullable,
# or
#       _Null_unspecified) [-Wnullability-completeness]
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:note139: :35
# :       insert '_Nullable'note : if
# the       insertpointer  '_Nullable'may  ifbe  thenull pointer
#  may be null
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
#                                            _Nullable        fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:139:35: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:note139: :35
# :       insert '_Nonnull'note : if
# the       insertpointer  '_Nonnull'should  ifnever  thebe  pointernull should
#  never be null
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                           ^
#         fpos_t  (* _Nullable _seek) (void *, fpos_t, int);
#                                            _Nonnull                                          ^
#
#                                            _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:: 140:32warning::
# warning      : pointer is
#        missingpointer  ais  nullabilitymissing  typea  specifiernullability  (_Nonnull,type  _Nullable,specifier  or(_Nonnull,
#        _Nullable,_Null_unspecified)  or[-Wnullability-completeness]
#
# _Null_unspecified) [-Wnullability-completeness]
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:: 140:32note::
#       noteinsert:  '_Nullable'
#        ifinsert  the'_Nullable'  pointerif  maythe  bepointer  nullmay
# be null
#         int     (* _Nullable _write)(void *, const char *, int);
#                                           ^
#                                            _Nullable        int     (* _Nullable _write)(void *, const char *, int);
#
#                                           ^
#                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:32: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.hnote:: 140:
# 32      :insert  '_Nonnull' noteif:  the
#        pointerinsert  should'_Nonnull'  neverif  bethe  nullpointer
# should never be null
#         int     (* _Nullable _write)(void *, const char *, int);        int     (* _Nullable _write)(void *, const char *, int);
#
#                                           ^                                          ^
#
#                                            _Nonnull                                           _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h::140140::4646::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
#         int     (* _Nullable _write)(void *, const char *, int);        int     (* _Nullable _write)(void *, const char *, int);
#
#                                                         ^                                                        ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h::140140::4646::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
#         int     (* _Nullable _write)(void *, const char *, int);        int     (* _Nullable _write)(void *, const char *, int);
#
#                                                         ^                                                        ^
#
#                                                          _Nullable                                                         _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:140:46: note:
#       insert '_Nonnull' if the pointer should /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.hnever: 140be: 46null:
# note:
#       insert '_Nonnull' if the        int     (* _Nullable _write)(void *, const char *, int);
# pointer                                                         ^should
#  never                                                          _Nonnullbe
#  null
#         int     (* _Nullable _write)(void *, const char *, int);
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h                                                        ^:
# 144:18                                                         _Nonnull:
#  warning:
#       pointer is missing a nullability type specifier/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h :(_Nonnull,144 :_Nullable,18 :or
#       _Null_unspecified)warning : [-Wnullability-completeness]
#
#       pointer is missing a nullability type         struct __sFILEX *_extra; /* additions to FILE to not break ABI */specifier
#  (_Nonnull,                        ^
# _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:144:        struct __sFILEX *_extra; /* additions to FILE to not break ABI */18
# :                         ^
# note:
#       insert '_Nullable' if the pointer may be/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h :null144:
# 18: note:
#       insert '_Nullable' if        struct __sFILEX *_extra; /* additions to FILE to not break ABI */
# the                         ^pointer
#  may                           _Nullable be
#  null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h:        struct __sFILEX *_extra; /* additions to FILE to not break ABI */144
# :18                        ^:
#                            _Nullable note
# :
#       insert '_Nonnull' if the pointer should never/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/_stdio.h :be144 :null18:
#  note:
#       insert '_Nonnull' if the        struct __sFILEX *_extra; /* additions to FILE to not break ABI */
# pointer                         ^should
#  never                           _Nonnull be
#  null
#         struct __sFILEX *_extra; /* additions to FILE to not break ABI */
#                         ^
#                           _Nonnull
# In file included from In file included from /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.c/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c::218:
# :
# In file included from In file included from /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.h/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h::725:
# :
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h::2567:
# :13/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:: 67:13warning::  warning
# :       pointer
# is       pointermissing  isa  missingnullability  atype  nullabilityspecifier  type(_Nonnull,  specifier_Nullable,  (_Nonnull,or
# _Nullable,       _Null_unspecified)or
# [-Wnullability-completeness]      _Null_unspecified)
#  [-Wnullability-completeness]
# extern FILE *__stdinp;extern FILE *__stdinp;
#
#             ^            ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h::6767::1313::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable' if the pointer  if the pointer may be nullmay
# be null
# extern FILE *__stdinp;
#             ^
#               _Nullable extern FILE *__stdinp;
#
#             ^
#               _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h67::6713::13 : note: note
# :       insert
#        '_Nonnull'insert  if'_Nonnull'  theif  pointerthe  shouldpointer  nevershould  benever  nullbe
# null
# extern FILE *__stdinp;extern FILE *__stdinp;
#
#             ^            ^
#
#               _Nonnull               _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h::386386::4141::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable, or
#        or_Null_unspecified)
#        [-Wnullability-completeness]_Null_unspecified)
# [-Wnullability-completeness]
#                  int (* _Nullable)(void *, const char *, int),
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:41/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:: 386:41note::
#       noteinsert:  '_Nullable'
#        ifinsert  the'_Nullable'  pointerif  maythe  bepointer  nullmay
# be null
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
#                  int (* _Nullable)(void *, const char *, int),
#                                          _Nullable                                        ^
#
#                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h::41386:: 41: note: note
# :       insert
#        '_Nonnull'insert  if'_Nonnull'  theif  pointerthe  shouldpointer  nevershould be  nullnever
# be null
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
#                                          _Nonnull
#                  int (* _Nullable)(void *, const char *, int),
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h                                         _Nonnull:
# 386:55: warning:
#       pointer is /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.hmissing a: nullability386 :type55 :specifier  (_Nonnull, warning_Nullable,:  or
#
#             _Null_unspecified)pointer  [-Wnullability-completeness]is
# missing a nullability type specifier (_Nonnull, _Nullable, or
#                  int (* _Nullable)(void *, const char *, int),
# _Null_unspecified)                                                       ^[-Wnullability-completeness]
#
#                  int (* _Nullable)(void *, const char *, int),
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h                                                      ^:
# 386:55: note:
#       insert '_Nullable' if the pointer may be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:386:55: note:
#       insert '_Nullable' if                 int (* _Nullable)(void *, const char *, int),
# the                                                       ^pointer
#  may                                                        _Nullablebe
#  null
#                  int (* _Nullable)(void *, const char *, int),
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h                                                      ^:
# 386:55                                                       _Nullable:
#  note:
#       insert '_Nonnull' if the pointer should /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.hnever: 386be: 55null:
# note:
#       insert '_Nonnull' if the pointer should never be null                 int (* _Nullable)(void *, const char *, int),
#
#                                                       ^
#                                                        _Nonnull
#                  int (* _Nullable)(void *, const char *, int),
#                                                       ^
#                                                        _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:warning387: :44:
#        pointer warningis:  missing
# a       pointernullability  istype  missingspecifier  a(_Nonnull, _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
#  nullability type specifier (_Nonnull, _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: note                 fpos_t (* _Nullable)(void *, fpos_t, int),:
#                                            ^
#
#       insert '_Nullable' if the pointer may be null/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h
# :387:44: note:
#       insert '_Nullable' if the pointer may                 fpos_t (* _Nullable)(void *, fpos_t, int),
# be                                            ^null
#
#                                             _Nullable
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
#                                             _Nullable/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h
# :387:44: note:
#       insert '_Nonnull' if the pointer should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:387:44: note:
#       insert '_Nonnull' if the pointer should never be                 fpos_t (* _Nullable)(void *, fpos_t, int),
# null                                           ^
#
#                                             _Nonnull
#                  fpos_t (* _Nullable)(void *, fpos_t, int),
#                                            ^
#                                             _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41: warning:
#       pointer is missing /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.ha: 388nullability: 41type:  specifier (_Nonnull,warning :
#       pointer_Nullable,  is missing a nullability ortype
#        specifier_Null_unspecified)  (_Nonnull,[-Wnullability-completeness] _Nullable,
#  or
#       _Null_unspecified) [-Wnullability-completeness]
#                  int (* _Nullable)(void *));
#                                         ^
#                  int (* _Nullable)(void *));
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:: 388:41note::
#       noteinsert:  '_Nullable'
#        ifinsert  the'_Nullable'  pointerif  maythe  bepointer  nullmay
#  be null
#                  int (* _Nullable)(void *));
#                                         ^
#                                          _Nullable
#                  int (* _Nullable)(void *));
#                                         ^
#                                          _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:388:41: note:
#       insert '_Nonnull' if the pointer should never be/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h :null388:
# 41: note:
#       insert '_Nonnull'                 int (* _Nullable)(void *));
# if                                         ^the
#  pointer                                          _Nonnullshould
#  never be null
#                  int (* _Nullable)(void *));
#                                         ^
#                                          _Nonnull/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h
# :384:6: warning:
#       pointer is/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h :missing384 :a6 :nullability  type warningspecifier:
#       pointer(_Nonnull,  is_Nullable,  missingor
# a       _Null_unspecified)nullability  [-Wnullability-completeness]
# type specifier FILE    *funopen(const void *,(_Nonnull,
#  _Nullable,        ^
# or
#       _Null_unspecified) [-Wnullability-completeness]
# FILE    *funopen(const void *,
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384:6: note: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384
# :      6insert: note:
#       insert '_Nullable' if the'_Nullable'  pointerif  maythe  bepointer  nullmay be null
#
# FILE    *funopen(const void *,FILE    *funopen(const void *,
#
#         ^        ^
#
#           _Nullable           _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h:384:6: note: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdio.h
# :      384insert: 6'_Nonnull':  if thenote : pointer should never
# be       nullinsert
# '_Nonnull' if the pointer should neverFILE    *funopen(const void *,
# be         ^null
#
#           _Nonnull
# FILE    *funopen(const void *,
#         ^
#           _Nonnull
# In file included from In file included from /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.c/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c::218:
# :
# In file included from In file included from /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/fortranobject.h/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h::734:
# :
# In file included from /Users/swd8g/.pyenv/versions/3.8.0/include/python3.8/Python.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::34134:
# :25/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:: 134:25warning::
# warning      pointer:  is
# missing       pointera  isnullability  missingtype  aspecifier  nullability(_Nonnull,  type_Nullable,  specifieror
# (_Nonnull,       _Null_unspecified)_Nullable,  [-Wnullability-completeness]or
#
#       _Null_unspecified) [-Wnullability-completeness]
# double   atof(const char *);
#                          ^double   atof(const char *);
#
#                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:134/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::25134:: 25: note: note
# :       insert
#        '_Nullable'insert  if'_Nullable'  theif  pointerthe  maypointer  bemay  nullbe
# null
# double   atof(const char *);
# double   atof(const char *);                         ^
#
#                          ^
#                           _Nullable
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h134::13425::25 : note: note:
#
# insert       insert'_Nonnull'  if'_Nonnull'  theif  pointerthe  shouldpointer  nevershould  benever  nullbe
# null
# double   atof(const char *);
# double   atof(const char *);                         ^
#
#                          ^
#                           _Nonnull
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::135135::2222::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# int      atoi(const char *);int      atoi(const char *);
#
#                          ^                         ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::135135::2222::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
# int      atoi(const char *);int      atoi(const char *);
#
#                          ^                         ^
#
#                           _Nullable                          _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::135135::2222::  notenote: :
#
#             insertinsert  '_Nonnull''_Nonnull'  ifif  thethe  pointerpointer  shouldshould  nevernever  bebe  nullnull
#
# int      atoi(const char *);int      atoi(const char *);
#
#                          ^                         ^
#
#                           _Nonnull                          _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::136136::2323::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# long     atol(const char *);long     atol(const char *);
#
#                          ^                         ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::136136::2323::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
# long     atol(const char *);long     atol(const char *);
#                          ^
#
#                          ^                          _Nullable
#
#                           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:136:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h23::136 :23:note :
# note      : insert
# '_Nonnull'       insertif  '_Nonnull'the  ifpointer  theshould  pointernever  shouldbe  nevernull be
#  null
# long     atol(const char *);
# long     atol(const char *);                         ^
#
#                          ^
#                           _Nonnull
#                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::139139::2020::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
#          atoll(const char *);         atoll(const char *);
#
#                           ^                          ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::139139::2020::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
#          atoll(const char *);         atoll(const char *);
#
#                           ^                          ^
#
#                            _Nullable                           _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::139139::2020::  notenote: :
#
#             insertinsert  '_Nonnull''_Nonnull'  ifif  thethe  pointerpointer  shouldshould  nevernever  bebe  nullnull
#
#          atoll(const char *);         atoll(const char *);
#
#                           ^                          ^
#
#                            _Nonnull                           _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::141141::2626::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,void    *bsearch(const void *__key, const void *__base, size_t __nel,
#
#                             ^                            ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::141141::2626::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,void    *bsearch(const void *__key, const void *__base, size_t __nel,
#
#                             ^                            ^
#
#                               _Nullable                               _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::141141::2626::  notenote: :
#
#             insertinsert  '_Nonnull''_Nonnull'  ifif  thethe  pointerpointer  shouldshould  nevernever  bebe  nullnull
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,void    *bsearch(const void *__key, const void *__base, size_t __nel,
#
#                             ^                            ^
#
#                               _Nonnull                               _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::141141::4545::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype specifier  (_Nonnull, _Nullable,specifier or
# (_Nonnull,       _Null_unspecified)_Nullable,  [-Wnullability-completeness]or
#
#       _Null_unspecified) [-Wnullability-completeness]
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:45: note:
#       /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.hinsert: 141'_Nullable': 45if:  the pointernote : may
# be       insertnull '_Nullable'
#  if the pointer may be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nullable
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141:45: note:
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h      :insert141 :'_Nonnull'45 :if  the notepointer:  should
#        neverinsert  be'_Nonnull'  nullif
# the pointer should never be null
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nonnull
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#                                                ^
#                                                  _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:warning: 142:
#       59pointer:  is missingwarning : a nullability
#        typepointer  specifieris  (_Nonnull,missing  _Nullable,a  ornullability
#        type_Null_unspecified)  specifier[-Wnullability-completeness] (_Nonnull,
#  _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                           ^
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: note/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h: :142
# :      59insert:  '_Nullable' ifnote : the
# pointer       insertmay  '_Nullable'be  ifnull the
#  pointer may be null
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                           ^
#                                                            _Nullable  ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#
#                                                           ^
#                                                            _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:59: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:note142: :59
# :       insert '_Nonnull'note : if
# the       insertpointer  '_Nonnull'should  ifnever  thebe  pointernull should
#  never be null
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#                                                           ^
#                                                            _Nonnull  ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#
#                                                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h                                                           _Nonnull:
# 142:73: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:warning142: :73:
#       pointerwarning : is missing
#        apointer  nullabilityis  typemissing  specifiera  (_Nonnull,nullability  _Nullable,type  orspecifier
#        (_Nonnull,_Null_unspecified)  _Nullable,[-Wnullability-completeness] or
#
#       _Null_unspecified) [-Wnullability-completeness]
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));
#   ...size_t __width, int (* _Nonnull __compar)(const void *, const void *));                                                                        ^
#
#                                                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:142:73:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h :142:note73: :
#       insertnote : '_Nullable'
# if       insertthe  '_Nullable'pointer  ifmay  thebe  pointernull may
#  be null
#   ...__width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                  ^
#                                                                   _Nullable
#   ...__width, int (* _Nonnull __compar)(const void *, const void *));
#                                                                  ^
#                                                                   _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h142::14273::73 : note: note:
#
# insert       insert'_Nonnull'  '_Nonnull'if  ifthe  thepointer  pointershould  shouldnever  neverbe  benull null
#
#   ...__width, int (* _Nonnull __compar)(const void *, const void *));
#   ...__width, int (* _Nonnull __compar)(const void *, const void *));                                                                 ^
#
#                                                                  ^
#                                                                   _Nonnull
#                                                                   _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h141::1416::6 : warning: warning:
#
# pointer       pointeris  ismissing  missinga  anullability  nullabilitytype  typespecifier  specifier(_Nonnull,  (_Nonnull,_Nullable,  _Nullable,or
# or
# _Null_unspecified)       _Null_unspecified)[-Wnullability-completeness] [-Wnullability-completeness]
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h141::1416::6 : note: note:
#
# insert       insert'_Nullable'  '_Nullable'if  ifthe  thepointer  pointermay  maybe  benull null
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
#         ^
#           _Nullable
#           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:141/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::6141:: 6: note: note
# :       inse
# rt      insert  '_Nonnull''_Nonnull'  ifif  thethe  pointerpointer  shouldshould  nevernever  bebe  nullnull
#
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#         ^
# void    *bsearch(const void *__key, const void *__base, size_t __nel,
#           _Nonnull         ^
#
#           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h::147147::2525::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# char    *getenv(const char *);char    *getenv(const char *);
#
#                            ^                           ^
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:25: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:note147: :
# 25      :insert  '_Nullable' noteif:  the
#        pointerinsert  may'_Nullable'  beif  nullthe
# pointer may be null
# char    *getenv(const char *);
#                            ^
#                             _Nullablechar    *getenv(const char *);
#
#                            ^
#                             _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:25: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.hnote:: 147:
# 25      :insert  '_Nonnull' noteif:  the
#        pointerinsert  should'_Nonnull'  neverif  bethe  nullpointer
# should never be nullchar    *getenv(const char *);
#
#                            ^
#                             _Nonnull
# char    *getenv(const char *);
#                            ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h                            _Nonnull:
# 147:6: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.hwarning:: 147:6
# :       pointer iswarning : missing a
#        nullabilitypointer  typeis  specifiermissing  (_Nonnull,a  _Nullable,nullability  ortype
#        specifier_Null_unspecified)  (_Nonnull,[-Wnullability-completeness] _Nullable,
#  or
#       _Null_unspecified) [-Wnullability-completeness]char    *getenv(const char *);
#
#         ^
# char    *getenv(const char *);
#         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:6: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:note147: :6
# :       insert '_Nullable'note : if
# the       insertpointer  '_Nullable'may  ifbe  thenull pointer
#  may be null
# char    *getenv(const char *);
#         ^
#           _Nullable char    *getenv(const char *);
#
#         ^
#           _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.h:147:6: note:
#       insert '_Nonnull' if the /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/stdlib.hpointer: 147should: 6never be null:
#  note:
#       insert '_Nonnull'char    *getenv(const char *);
# if         ^the
#  pointer          _Nonnull
# should never be null
# char    *getenv(const char *);
#         ^
#           _Nonnull
# ...
#
#                                         ^                                          _Nullable
#
#                                           _Nullable
# /Libra/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.hry/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h::97:9737::37 : note: note
#       insert:
#        insert'_Nonnull'  '_Nonnull'if  ifthe  thepointer  pointershould  shouldnever  neverbe  benull null
#
# int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
#                                         ^
#                                           _Nonnull
# int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
#                                         ^
#                                           _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:97/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h::6097:: 60:warning:
#       pointer is  missing a nullabilitywarning : type specifier
#        (_Nonnull,pointer  _Nullable,is  ormissing
#        a_Null_unspecified)  [-Wnullability-completeness]
# nullability type specifier (_Nonnull, _Nullable,int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
# or
#                                                                ^
# _Null_unspecified) [-Wnullability-completeness]
# int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
#                                                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:97:60: note:
#       insert '_Nullable' if the pointer may be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:97:60: int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
# note:                                                                ^
#
#       insert                                                                 _Nullable
# '_Nullable' if the pointer may be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:97:60: note:
#       int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);insert
#  '_Nonnull'                                                               ^
# if the                                                                 _Nullable
# pointer should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:97:60: int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
# note:                                                                ^
#
#       insert                                                                  _Nonnull'_Nonnull'
#  if the pointer should never be null
# int     sigprocmask(int, const sigset_t * __restrict, sigset_t * __restrict);
#                                                                ^
#                                                                  _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:100:31: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.hwarning:: 100:31
# :       pointer is missing warning: a
#        pointernullability  istype  missingspecifier  a(_Nonnull,  nullability_Nullable,  typeor
# specifier       _Null_unspecified)(_Nonnull,  [-Wnullability-completeness]_Nullable,
# or
#       _Null_unspecified) [-Wnullability-completeness]
# int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);
#                                   ^
# int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);
#                                   ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:100:31: /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:100note:: 31:
#       insertnote : '_Nullable'
#       insertif  '_Nullable' theif  pointerthe  maypointer  bemay  nullbe
# null
# int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);
# int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);                                  ^
#
#                                   ^
#                                    _Nullable                                   _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h100::10031::31 : note: note:
#
# insert       insert'_Nonnull'  '_Nonnull'if  ifthe  thepointer  pointershould  shouldnever  neverbe  benull null
#
# int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);int     sigsuspend(const sigset_t *) __DARWIN_ALIAS_C(sigsuspend);
#
#                                   ^                                  ^
#
#                                    _Nonnull                                   _Nonnull
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h::101101::2828::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#
#                                ^
#                                ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h::101101::2828::  notenote: :
#
#             insertinsert  '_Nullable''_Nullable'  ifif  thethe  pointerpointer  maymay  bebe  nullnull
#
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#
#                                ^                               ^
#
#                                  _Nullable                                 _Nullable
#
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:101:28/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:: 101:28note::
#       noteinsert:  '_Nonnull'
#        ifinsert  the '_Nonnull'pointer  ifshould  thenever  pointerbe  shouldnull never
#  be null
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#                                ^
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#                                  _Nonnull                               ^
#
#                                  _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h::101101::4646::  warningwarning: :
#
#             pointerpointer  isis  missingmissing  aa  nullabilitynullability  typetype  specifierspecifier  (_Nonnull,(_Nonnull,  _Nullable,_Nullable,  oror
#
#             _Null_unspecified)_Null_unspecified)  [-Wnullability-completeness][-Wnullability-completeness]
#
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#                                                  ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:101
# :46: note:                                                  ^
#
#       insert '_Nullable' if the pointer may be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.hint     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...:
# 101:                                                 ^46: note:
#
#       insert '_Nullable' if                                                   _Nullable
# the pointer may be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:101:46: int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
# note                                                 ^:
#
#       insert '_Nonnull'                                                   _Nullable
# if the pointer should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:101:46: note:
#       insert int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...'_Nonnull'
#  if                                                 ^
# the pointer                                                   _Nonnull
# should never be null
# int     sigwait(const sigset_t * __restrict, int * __restrict) __DARWIN_...
#                                                  ^
#                                                    _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:103:39: warning/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h: :103:
# 39      :pointer  is warningmissing:  a
# nullability       pointertype  isspecifier  missing(_Nonnull,  a_Nullable,  nullabilityor
# type       _Null_unspecified)specifier  [-Wnullability-completeness](_Nonnull,
# _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
# void    psignal(unsigned int, const char *);
#                                          ^
# void    psignal(unsigned int, const char *);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:103:39: note:
#       insert '_Nullable' if the pointer may be null
# void    psignal(unsigned int, const char *);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:103                                          _Nullable:
# 39: note:
#       insert '_Nullable' if the pointer may /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.hbe: 103null:39
# : note:
#       insert '_Nonnull' if void    psignal(unsigned int, const char *);the
#  pointer                                         ^
# should never                                          _Nullable
# be null
# void    psignal(unsigned int, const char *);
#                                          ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h                                          _Nonnull:
# 103:39: note:
#       insert '_Nonnull' if the pointer should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:31: void    psignal(unsigned int, const char *);
# warning:                                          ^
#
#                                                 _Nonnullpointer
#  is missing a nullability type specifier (_Nonnull, _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:31: int     sigvec(int, struct sigvec *, struct sigvec *);
# warning                                  ^:
#
#       pointer is missing/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h a nullability type :specifier (_Nonnull,106 :_Nullable,31 :or
#       _Null_unspecified)note : [-Wnullability-completeness]
#
#       insert '_Nullable' if the pointer may be nullint     sigvec(int, struct sigvec *, struct sigvec *);
#
#                                   ^
# int     sigvec(int, struct sigvec *, struct sigvec *);
#                                   ^
#                                    _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:31: note:
#       insert '_Nullable' if the pointer may be/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h :null106:
# 31: note:
#       insert '_Nonnull' if int     sigvec(int, struct sigvec *, struct sigvec *);
#                                   ^
# the                                    _Nullablepointer
#  should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:int     sigvec(int, struct sigvec *, struct sigvec *);106
# :31                                  ^:
#                                     _Nonnullnote
# :
#       insert '_Nonnull' if the pointer should never be null
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:48: warning:
#       pointerint     sigvec(int, struct sigvec *, struct sigvec *);
# is                                   ^missing
#  a                                    _Nonnullnullability
#  type specifier (_Nonnull, _Nullable, or
#       _Null_unspecified) [-Wnullability-completeness]/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h
# :106:48: warning: int     sigvec(int, struct sigvec *, struct sigvec *);
#
#                                                          ^pointer
#  is /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:missing106 :a48 :nullability  type notespecifier:  (_Nonnull,
#        _Nullable,insert  or'_Nullable'
#        if_Null_unspecified)  the[-Wnullability-completeness] pointer
#  may be null
# int     sigvec(int, struct sigvec *, struct sigvec *);
#                                                    ^
# int     sigvec(int, struct sigvec *, struct sigvec *);
#                                                    ^
#                                                     _Nullable
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:48: note:
#       insert '_Nullable'/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h :if106 :the48 :pointer  may notebe:  null
#
# insert '_Nonnull' if the pointer should never beint     sigvec(int, struct sigvec *, struct sigvec *);
# null                                                   ^
#
#                                                     _Nullable
# int     sigvec(int, struct sigvec *, struct sigvec *);
#                                                    ^
#                                                     _Nonnull
# /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include/signal.h:106:48: note:
#       insert '_Nonnull' if the pointer should never be null
# int     sigvec(int, struct sigvec *, struct sigvec *);
#                                                    ^
#                                                     _Nonnull
# /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8/nbody_derivativesmodule.c:113:12: warning:
#       unused function 'f2py_size' [-Wunused-function]
# static int f2py_size(PyArrayObject* var, ...)
#            ^
# 218 warnings generated.
# 217 warnings generated.
# INFO: compiling Fortran sources
# INFO: Fortran f77 compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# INFO: compile options: '-I/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8 -I/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/core/include -I/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8 -c'
# INFO: gfortran:f90: nbody_derivatives.f90
# clang (LLVM option parsing): Unknown command line argument '-x86-pad-for-align=false'.  Try: 'clang (LLVM option parsing) --help'
# clang (LLVM option parsing): Did you mean '--x86-slh-loads=false'?
# error: Command "/usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops -I/var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/src.macosx-10.15-x86_64-3.8 -I/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/numpy/core/include -I/Users/swd8g/.pyenv/versions/3.8.0/include/python3.8 -c -c nbody_derivatives.f90 -o /var/folders/88/7vcftb255n1gnhcrq9t_ldfc0000gn/T/tmpjzvh5izo/nbody_derivatives.o" failed with exit status 1

# %%
import nbody_derivatives as nbd
import importlib
importlib.reload(nbd)

def fortran_derivatives(pos, vel):
    return nbd.derivs(pos, vel, M)

# %prun positions = run_Nbody_rk2(frames*tframe, tframe, dt, fortran_derivatives)
#print(positions)
fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positions), frames=frames, interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 import nbody_derivatives as nbd
#       2 import importlib
#       3 importlib.reload(nbd)
#
# ModuleNotFoundError: No module named 'nbody_derivatives'

# %% [markdown]
# This turned out be the fastest, just a bit faster than Cython. If you are comfortable coding in Fortran, `f2py` is a convenient method for speeding up your code.

# %% [markdown]
# ## 3. Parallelization Introduction
#
# Parallelization is the process of running your code on multiple CPUs or CPU cores simultaneously to speed up the calculation.  We will discuss parallelization generally in next week's lecture, but the focus will be on OpenMP and MPI, mainly with applications to C/C++ and Fortran.  That said, there are a number of options for parallelizing Python code.
#
# There are many ways of doing parallelization in Python. One way we will discuss later in the class is using apache spark. This allows parallel processing of large distributed data sets, which is used widely in the tech industry for big data. Other frameworks like dask and ray are also becoming popular.
#
# Here we will focus on a simple way to do this using Python's `multiproccess` module. This method only works on one node, but with nodes on many machines now containing $\gtrsim 100$ CPU cores, this is sufficient for many applicaionts.

# %%
# Python built-in is multiprocessing, but doesn't play well with
# Jupyter so using multiprocess instead
import multiprocess  

count = 4
pool = multiprocess.Pool(processes=count)

def Nbody_derivatives3(pos, vel):
    dpdt = vel
    dvdt = np.zeros_like(vel)
    for i in range(N_bodies) :
        for j in range(N_bodies):
            if i == j: 
                continue
            r = np.linalg.norm(pos[j]-pos[i])
            mass = M[j]
            rhat = (pos[i] - pos[j])/r
            dvdt[i] += -mass/(r*r)*rhat
        
    return dpdt, dvdt

def onebody_derivatives(i, pos, vel):
    dvdt = np.zeros(3)
    for j in range(N_bodies) :
        if i == j : 
            continue
        r = np.linalg.norm( pos[j]-pos[i])
        mass = M[j]
        rhat = (pos[j] - pos[i])/r
        dvdt += -mass/(r*r)*rhat
        
    return dvdt

def parallel_Nbody_derivatives(pos, vel):
    dpdt = vel
    res = pool.starmap(onebody_derivatives, zip(range(N_bodies), [pos] * N_bodies, [vel]*N_bodies))
    dvdt = np.array(res)
    return dpdt, dvdt

# %prun positionsp = run_Nbody_rk2(frames*tframe, tframe, dt, p0, v0, parallel_Nbody_derivatives)
# Out:
#          77207 function calls in 20.000 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8000   19.646    0.002   19.646    0.002 {method 'acquire' of '_thread.lock' objects}
#      2000    0.093    0.000    0.093    0.000 {built-in method numpy.array}
#         1    0.067    0.067   19.999   19.999 283640628.py:27(run_Nbody_rk2)
#      2000    0.030    0.000    0.097    0.000 pool.py:468(_map_async)
#      2000    0.022    0.000    0.022    0.000 threading.py:222(__init__)
#      2000    0.022    0.000   19.930    0.010 1207892007.py:34(parallel_Nbody_derivatives)
#      2000    0.019    0.000   19.674    0.010 threading.py:270(wait)
#      2000    0.013    0.000   19.692    0.010 threading.py:540(wait)
#      2000    0.012    0.000    0.045    0.000 pool.py:744(__init__)
#      2000    0.011    0.000   19.815    0.010 pool.py:366(starmap)
#      2000    0.009    0.000    0.009    0.000 {method 'put' of '_queue.SimpleQueue' objects}
#      2000    0.007    0.000    0.052    0.000 pool.py:791(__init__)
#      2000    0.007    0.000   19.707    0.010 pool.py:764(get)
#      2000    0.006    0.000    0.032    0.000 threading.py:505(__init__)
#      2000    0.005    0.000    0.007    0.000 threading.py:258(_acquire_restore)
#      4000    0.005    0.000    0.005    0.000 {built-in method _thread.allocate_lock}
#      2000    0.004    0.000   19.696    0.010 pool.py:761(wait)
#      2000    0.003    0.000    0.004    0.000 pool.py:753(ready)
#      2000    0.003    0.000    0.003    0.000 pool.py:348(_check_running)
#      2000    0.002    0.000    0.003    0.000 threading.py:249(__exit__)
#      2000    0.001    0.000    0.003    0.000 threading.py:246(__enter__)
#      1000    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      2000    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#      2000    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#      2000    0.001    0.000    0.001    0.000 {method '__enter__' of '_thread.lock' objects}
#      2000    0.001    0.000    0.002    0.000 threading.py:255(_release_save)
#      2000    0.001    0.000    0.002    0.000 threading.py:261(_is_owned)
#      8000    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#      2000    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      2000    0.001    0.000    0.001    0.000 threading.py:513(is_set)
#         1    0.001    0.001   19.999   19.999 <string>:1(<module>)
#       103    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      2000    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000   20.000   20.000 {built-in method builtins.exec}
#      2000    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#      2000    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       100    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-11:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/queues.py", line 359, in get
#     res = self._reader.recv_bytes()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/swd8g/.pyenv/versions/3.8.0/lib/python3.8/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
fig, ax = plt.subplots()
ani = FuncAnimation(fig, lambda i : animate(i, positionsp), frames=frames, interval=50, repeat=False)
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# The code actually runs slower! This is a common problem with parallelization -- particularly in a shared memory environment. The profiler output indicates why: almost all of the time is spent in a method `aquire` of a `_thread.lock` object. In other words it has to lock down memory to make sure that processes don't inferfere with each other. Parallelization needs to beat this overhead by doing lots of work, but the amount of work in this case is too small.
#
# Parallelization is good if there is no contention *and* the amount of work per core is large.    But generally for most of the problems you deal with in Python, this is not the case. This is why single process optimization is the best place to start when trying to speed up code.

# %% [markdown]
# ## **In-class Completion**
#
# The following exercises will be done in class during the Thursday lab, but you are encouraged to read the following discusion before arriving to class.
#
# For a simple application, lets consider the circular motion caused by gravity in the limit that the central mass is much bigger than the oribiting mass.  In this case we can reduce it to a system of first order ODEs given by
# $$
# \frac{d \mathbf{r}}{dt} = \mathbf{v}
# $$
# and
# $$
# \frac{d \mathbf{v}}{dt} = -\frac{G M \mathbf{r}}{r^3}
# $$
# Since circular motion is confined to a plane, we can write the vectors as 2D e.g. $\mathbf{r} = (x, y)$ and $\mathbf{v} = (v_x, v_y)$.
#
# Start by writing your own function for the derivatives. For simplicity, choose units so that $G M = 4 \pi^2$. Given that Keplers Law is
# $$
# 4\pi^2 a^3 = G M P^2
# $$
# this reduces to $a^3 = P^2$.
#
# Lets try running this problem, I have already provided you a function for the derivatives.  Note that I have assumed a single vector of independent variables of the form $\mathbf{y} = (x,y,v_x,v_y)$. I have also copied two of the integrators above and written a function to run the integration.

# %%
def derivatives_2d(t, y, GM=None):

    # y[0:2] -> (x,y)
    # y[2:4] -> (vx, vy)
    if GM == None:
        GM = 4*np.pi**2

    dydt = np.empty_like(y)

    dydt[0:2] = y[2:4]
    r = np.sqrt(np.sum(y[0:2]**2))
    dydt[2:4] = -GM * y[0:2] / r**3
    return  dydt

def euler(derivatives, t, dt, y):
    return y + derivatives(t, y) * dt
    
def rk2(derivatives, t, dt, y):
    k1 = derivatives(t, y)
    k2 = derivatives(t, y+k1*0.5*dt)
    return y+dt*k2

def run_integrate(tend, dt, p0, v0, derivatives, integrator, tstart=0.):
    t = tstart
    y = np.empty(4)
    y[0:2] = p0
    y[2:4] = v0
    vars = [y.copy()]
    tarr = [t]
    while t<tend :
        delta_t = min(tend-t,dt)
        y = integrator(derivatives, t, delta_t, y)
        t += delta_t
        tarr.append(t)
        vars.append(y.copy())
    
    return np.array(vars), np.array(tarr)

# %% [markdown]
# Lets define initial conditions for a circular orbint. If we choose $GM = 4\pi^2$, we get $P=1$ for $a=1$.

# %%
# define initial conditions so that the semi-major axis
# is a = 1, and the velocity is correct for cicular orbit
GM = 4.*np.pi**2
pos0 = np.array([0, 1])
vel0 = np.array([-np.sqrt(GM/pos0[1]), 0.])
dt = 0.1
tend = 1. # one orbit

# %% [markdown]
# Ok, lets see how this goes.  Lets try Euler's method first.

# %%
# run the integrator and plot the results
vars_eul, t_eul = run_integrate(tend, dt, pos0, vel0, derivatives_2d, euler)

fig = plt.figure()
ax = fig.add_subplot(111) # to set aspect ratio

# put a point at the origin
ax.scatter([0], [0], marker='o', color="r")

# draw the orbit
ax.plot(vars_eul[:,0], vars_eul[:,1], label='Euler')

ax.set_aspect("equal")
ax.legend()
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# This is pretty terrible. We wanted something like a circle!  Even worse than what one might have expected based on our integration of the sin function above.

# %%
# run the integrator and plot the results
vars_rk2, t_rk2 = run_integrate(tend, dt, pos0, vel0, derivatives_2d, rk2)

fig = plt.figure()
ax = fig.add_subplot(111) # to set aspect ratio

# put a point at the origin
ax.scatter([0], [0], marker='o', color="r")

# draw the orbit
ax.plot(vars_eul[:,0], vars_eul[:,1], label='Euler')
ax.plot(vars_rk2[:,0], vars_rk2[:,1], label='RK2')

ax.set_aspect("equal")
ax.legend()
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Ok. That is much better but still not awesome. Of course, we could improve things by lowering our dt and we would get covergence to the answer.  But, lets try the power of going to and even higher order method.
#
# **Write your own RK4 integrator and compare!**

# %%
# You can generallize the example above for RK2
def rk4(derivatives, t, dt, y):
    pass

# %%
#MY SOLUTION -- REMOVE
# You can generallize the example above for RK2
def rk4(derivatives, t, dt, y):
    k1 = derivatives(t, y)
    k2 = derivatives(t+0.5*dt, y+k1*0.5*dt)
    k3 = derivatives(t+0.5*dt, y+k2*0.5*dt)
    k4 = derivatives(t, y+k3*dt)

    return y+dt*(k1+2*(k2+k3)+k4)/6

# %%
# run the integrator with rk4
vars_rk4, t_rk4 = run_integrate(tend, dt, pos0, vel0, derivatives_2d, rk4)

fig = plt.figure()
ax = fig.add_subplot(111) # to set aspect ratio

# put a point at the origin
ax.scatter([0], [0], marker='o', color="r")

# draw the orbit
ax.plot(vars_rk2[:,0], vars_rk2[:,1], label='RK2')
ax.plot(vars_rk4[:,0], vars_rk4[:,1], label='RK4')

ax.set_aspect("equal")
ax.legend()
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Now we have something approximating a circle and we can do much better by reducing the time step:

# %%
# run the integrator with rk4
dt = 0.001
vars_smdt, t_smdt = run_integrate(tend, dt, pos0, vel0, derivatives_2d, rk4)

fig = plt.figure()
ax = fig.add_subplot(111) # to set aspect ratio

# put a point at the origin
ax.scatter([0], [0], marker='o', color="r")

# draw the orbit
ax.plot(vars_smdt[:,0], vars_smdt[:,1], label='0.001')
ax.plot(vars_rk4[:,0], vars_rk4[:,1], label='0.1')

ax.set_aspect("equal")
ax.legend()
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Looking like the answer is a good metric for assessing integrators when you know what the answer should be. But, you don't always have that luxury so it is good to check other diagnostics, such as consrerved quantities or other anticipated constants of the integration. For orbits, it is interesting to check the total orbital (gravitational plus kinetic) energy:
# $$
# E_{\rm tot} = \frac{1}{2} |{\bf v}|^2 - \frac{GM}{r}.
# $$
#
# **Write your own function to evaluate the total energy and see how it evolves**
#
# Take a vector (ndarray) $\mathbf{y} = (x,y,v_x,v_y)$ as the argument and return the energy.

# %%
def energy(y, GM=None):
    if (GM == None):
        GM = 4.*np.pi**2
    return 0.5*(y[2]**2 + y[3]**2) - GM/np.sqrt(y[0]**2 + y[1]**2)

# %%
# loop over time and compute energy
def compute_energy(vars, t):

    etot = np.empty_like(t)
    for i,y in enumerate(vars):
        etot[i] = energy(y)
    return t, etot

# %% [markdown]
# Lets see what happens for a longer integration over 10 orbits

# %%
dt = 0.01
tend = 10
vars_rk4, t_rk4 = run_integrate(tend, dt, pos0, vel0, derivatives_2d, rk4)

t, etot = compute_energy(vars_rk4, t_rk4)

plt.plot(t,etot)
plt.show()
print("E_final - E_initial: ",(etot[-1]-etot[0]))
# Out:
# E_final - E_initial:  -3.3764396992097545e-05

# %% [markdown]
# This looks ok. Energy is conserved to about one part in a million over 10 orbits with a stepsize 1/100 of an orbit.  But the fact that the energy is becoming more negative implies that it is becoming more bound and the orbit is slowly shrinking with time.
#
# Next, try an elliptical orbit with $x=0$, $y = (1 - e)$, $v_y=0$ and
# $$
# v_x = -\sqrt{\frac{GM}{a} \frac{1+e}{1-e}}
# $$
#
# Use your RK4 integrator

# %%
# define initial conditions so that the semi-major axis
# is a = 1 and e=0.5
GM = 4.*np.pi**2
a = 1.0
e = 0.6
pos0 = np.array([0, a*(1-e)])
vel0 = np.array([-np.sqrt(GM/a*(1+e)/(1-e)), 0.])
dt = 0.1
tend = 1. # one orbit

# %%
# run the integrator with rk4
dt = 0.01
tend = 10.
vars_e, t_e = run_integrate(tend, dt, pos0, vel0, derivatives_2d, rk4)

fig = plt.figure()
ax = fig.add_subplot(111) # to set aspect ratio

# put a point at the origin
ax.scatter([0], [0], marker='o', color="r")

# draw the orbit
ax.plot(vars_e[:,0], vars_e[:,1])

ax.set_aspect("equal")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Looks like an elliptical orbit.  Now check the energy.

# %%
t, etot = compute_energy(vars_e, t_e)
plt.plot(t,etot)
plt.show()
print("E_final - E_initial: ",(etot[-1]-etot[0]))
# Out:
# E_final - E_initial:  -0.04333469796873146

# %% [markdown]
# This is not nearly as good as the circular case. We see that energy conservation is particularly poor when the orbit is close to the origin (the star).  This would almost certainly be a problem if you wanted to do a longer term integration of the sysetm.
#
# This means that despite its relative accuracy, an integrator like RK4 is not the first choice when we want to integrate orbits for long times.  We will return to this next week.
